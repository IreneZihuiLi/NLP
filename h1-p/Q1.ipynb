# %%
#! /usr/bin/python

__author__="Daniel Bauer <bauer@cs.columbia.edu>"
__date__ ="$Sep 12, 2011"

import sys
from collections import defaultdict
from operator import itemgetter
import math

"""
Count n-gram frequencies in a data file and write counts to
stdout. 
"""

def simple_conll_corpus_iterator(corpus_file):
    """
    Get an iterator object over the corpus file. The elements of the
    iterator contain (word, ne_tag) tuples. Blank lines, indicating
    sentence boundaries return (None, None).
    """
    l = corpus_file.readline()
    while l:
        line = l.strip()
        if line: # Nonempty line
            # Extract information from line.
            # Each line has the format
            # word pos_tag phrase_tag ne_tag
            fields = line.split(" ")
            ne_tag = fields[-1] # tag
            #phrase_tag = fields[-2] #Unused
            #pos_tag = fields[-3] #Unused
            word = " ".join(fields[:-1])
            yield word, ne_tag
        else: # Empty line
            yield (None, None)                        
        l = corpus_file.readline()

def sentence_iterator(corpus_iterator):
    """
    Return an iterator object that yields one sentence at a time.
    Sentences are represented as lists of (word, ne_tag) tuples.
    """
    current_sentence = [] #Buffer for the current sentence
    for l in corpus_iterator:    
#             print ("***NOW",l) # Every line (every word) l -->  ('nucleotidase', 'I-GENE')
            if l==(None, None):
                if current_sentence:  #Reached the end of a sentence
                    yield current_sentence
                    current_sentence = [] #Reset buffer
                else: # Got empty input stream
                    sys.stderr.write("WARNING: Got empty input file/stream.\n")
                    raise StopIteration
            else:
                current_sentence.append(l) #Add token to the buffer

    if current_sentence: # If the last line was blank, we're done
#         print ("Current ",current_sentence)
        yield current_sentence  #Otherwise when there is no more token
                                # in the stream return the last sentence.
        #Current_sentence  [('When', 'O'), ('CSF', 'O'), ('joj', 'O'),...]  (read in as a key-value pairs collection)

def get_ngrams(sent_iterator, n):
    """
    Get a generator that returns n-grams over the entire corpus,
    respecting sentence boundaries and inserting boundary tokens.
    Sent_iterator is a generator object whose elements are lists
    of tokens. 每个句子前追加2个*，后追加一个STOP标志(w_boundary)
    """
    for sent in sent_iterator:
         # sent (list) --> [('omparison', 'O'), ('with', 'O'),  ...] (Tupels in every sentence)
         #Add boundary symbols to the sentence
         w_boundary = (n-1) * [(None, "*")]
         w_boundary.extend(sent)
         w_boundary.append((None, "STOP"))
         #Then extract n-grams
        
         ngrams = (tuple(w_boundary[i:i+n]) for i in range(len(w_boundary)-n+1))
         for n_gram in ngrams: #Return one n-gram at a time
#             print (n_gram)
            yield n_gram      

#         ngrams
#         (1, 2, 3)
#         (2, 3, 4)
#         (3, 4, 5)
#         (4, 5, 6)
#         (5, 6, 7)
#         >>> 类似这种
#  返回的是这样：
# ((None, '*'), (None, '*'), ('omparison', 'O'))
# ((None, '*'), ('omparison', 'O'), ('with', 'O'))
# (('omparison', 'O'), ('with', 'O'), ('alkaline', 'I-GENE'))


class Hmm(object):
    """
    Stores counts for n-grams and emissions. 
    """

    def __init__(self, n=3):
        assert n>=2, "Expecting n>=2."
        self.n = n
        self.emission_counts = defaultdict(int)
        self.ngram_counts = [defaultdict(int) for i in range(self.n)]
        self.all_states = set()
        
#       stores emmision para: same type with counts. shape (word,tag):value   meaning em (word|tag)
        self.emision_parameters = defaultdict(float)
#       rare word list
        self.rare = list()
#       argmax word list :    word([tag,em],[tag,em],...)
        self.argmax_list = defaultdict(list)
        self.argmax_value = defaultdict(str)


    def train(self, corpus_file):
        """
        Count n-gram frequencies and emission probabilities from a corpus file.
        """
        ngram_iterator = \
            get_ngrams(sentence_iterator(simple_conll_corpus_iterator(corpus_file)), self.n)
        

        for ngram in ngram_iterator:
            #Sanity check: n-gram we get from the corpus stream needs to have the right length
            assert len(ngram) == self.n, "ngram in stream is %i, expected %i" % (len(ngram, self.n))

            tagsonly = tuple([ne_tag for word, ne_tag in ngram]) #retrieve only the tags    
        #  tagsonly 只收集 ne_tag
        #     ('*', '*', 'O')
        #     ('*', 'O', 'O')
        #     ('O', 'O', 'I-GENE')
            
            for i in range(2, self.n+1): #Count NE-tag 2-grams..n-grams
                self.ngram_counts[i-1][tagsonly[-i:]] += 1
            if ngram[-1][0] is not None: # If this is not the last word in a sentence
                self.ngram_counts[0][tagsonly[-1:]] += 1 # count 1-gram
                self.emission_counts[ngram[-1]] += 1 # and emission frequencies

            # Need to count a single n-1-gram of sentence start symbols per sentence
            if ngram[-2][0] is None: # this is the first n-gram in a sentence
                self.ngram_counts[self.n - 2][tuple((self.n - 1) * ["*"])] += 1
#             print (self.emission_counts)


    def write_counts(self, output, printngrams=[1,2,3]):
        """
        Writes counts to the output file object.
        Format:

        """
        # First write counts for emissions
        for word, ne_tag in self.emission_counts:            
            output.write("%i WORDTAG %s %s\n" % (self.emission_counts[(word, ne_tag)], ne_tag, word))


        # Then write counts for all ngrams
        for n in printngrams:            
            for ngram in self.ngram_counts[n-1]:
                ngramstr = " ".join(ngram)
                output.write("%i %i-GRAM %s\n" %(self.ngram_counts[n-1][ngram], n, ngramstr))

    def read_counts(self, corpusfile):

        self.n = 3
        self.emission_counts = defaultdict(int)
        self.ngram_counts = [defaultdict(int) for i in range(self.n)]
        self.all_states = set()

        for line in corpusfile:
            parts = line.strip().split(" ")
            count = float(parts[0])
            if parts[1] == "WORDTAG":
                ne_tag = parts[2]
                word = parts[3]
                self.emission_counts[(word, ne_tag)] = count
                self.all_states.add(ne_tag)
            elif parts[1].endswith("GRAM"):
                n = int(parts[1].replace("-GRAM",""))
                ngram = tuple(parts[2:])
                self.ngram_counts[n-1][ngram] = count
        
    
    def get_emission_paras(self):
    
        self.emision_parameters = defaultdict(float)
        for wordNtag,counts in self.emission_counts.items():
            tag = wordNtag[1] #get tag of the tuple
            tagCount = self.ngram_counts[0][(tag,)]
            emission = counts / tagCount
            self.emision_parameters[wordNtag]=emission
            
            
        print (self.emision_parameters,'\n')
            
    def replaceRare(self,training_file,trainingChange_file):
        for wordNtag,counts in self.emission_counts.items():
            if counts < 5:
                print ('Now',wordNtag,counts)
                self.rare.append(wordNtag[0])
                
#         print (self.rare)
        
        l = training_file.readline()
        print (l)
        i = 0
        while l:
            if i%1000==0: print ('Now line',i)
            line = l.strip()
            if line: # Nonempty line
                
                fields = line.split(" ")
                ne_tag = fields[-1] # tag
                word = fields[0]
                if word in self.rare:
                    newline="%s %s\n" % ('_RARE_',ne_tag)
                    print (line,'-->')
                    print (newline)
                    trainingChange_file.write(newline)
                else:
                    trainingChange_file.write(l)

            else: # Empty line
                l = training_file.readline()
                trainingChange_file.write('\n')

#                 print ("Not Replaced!!!")
                
            l = training_file.readline()
        
        trainingChange_file.close()


    def get_argmax(self):
        #buid argmax list
        for wordNtag,values in self.emision_parameters.items():                
            self.argmax_list[wordNtag[0]].append((wordNtag[1],values))
        #build argmax real tag
        for word,values in self.argmax_list.items():
            tag = max(values,key=itemgetter(1))[0]
            self.argmax_value[word]=tag
            
        print(self.argmax_value)
        
    def write_prediction(self,testing,output):
        # read in word first
        for line in testing:
            word = line.strip()
            if word:
                tag=self.argmax_value[word]
                if tag:
                    output.write("%s %s\n" % (word, tag))
                else:
                    tag=self.argmax_value['_RARE_']
#                     print ('New word',tag)
                    output.write("%s %s\n" % (word, tag))
            else:
                output.write("\n")
        
                
#         # write (word tag) 
#         for word, tag in self.argmax_value.items():            
#             output.write("%s %s\n" % (word, tag))
        print ("Finish!")
        output.close()

        


def usage():
    print ("""
    python count_freqs.py [input_file] > [output_file]
        Read in a gene tagged training input file and produce counts.
    """)

if __name__ == "__main__":

    try:
#         input = file(sys.argv[1],"r")
        input = open("gene.counts",'r')
        training = open("mygenebig.train",'r')
        trainingC = open("mygenebig.train.replaced",'w')
        
        testing = open('gene.test','r')
        prediction = open("gene_test.p1.out",'w');
        
    except IOError:
        sys.stderr.write("ERROR: Cannot read inputfile %s.\n" % arg)
        sys.exit(1)
    
    # Initialize a trigram counter
    counter = Hmm(3)
    # Collect counts
#     counter.train(input)
    
    #Q1a: Read the counts
    counter.read_counts(input)
    counter.get_emission_paras()
    
    #Q1b: Replace
    counter.replaceRare(training,trainingC)

#     Q1c: Argmax
#     counter.get_argmax()
#     counter.write_prediction(testing,prediction)
# Out:
# Now ('caecal', 'O') 1.0
# Now ('Ratio', 'O') 1.0
# Now ('postmortem', 'O') 1.0
# Now ('Glucocorticoid', 'O') 2.0
# Now ('131', 'I-GENE') 1.0
# Now ('immunopathology', 'O') 1.0
# Now ('PVL', 'O') 1.0
# Now ('FI', 'O') 1.0
# Now ('EtHgCl', 'O') 2.0
# Now ('DU249', 'O') 1.0
# Now ('safely', 'O') 1.0
# Now ('Reye', 'O') 1.0
# Now ('(/)', 'O') 1.0
# Now ('claudication', 'O') 2.0
# Now ('frit', 'O') 1.0
# Now ('phosphorous', 'O') 1.0
# Now ('corpus', 'O') 2.0
# Now ('heparinization', 'O') 1.0
# Now ('entorhinal', 'O') 2.0
# Now ('Vti1p', 'I-GENE') 1.0
# Now ('hypokinetic', 'O') 1.0
# Now ('3213', 'O') 1.0
# Now ('OKs', 'O') 1.0
# Now ('Impulsiveness', 'O') 1.0
# Now ('valine', 'O') 4.0
# Now ('LOH', 'O') 3.0
# Now ('Spinacia', 'O') 1.0
# Now ('27S', 'I-GENE') 1.0
# Now ('A23187', 'O') 3.0
# Now ('sire', 'O') 1.0
# Now ('hydroxyacyl', 'I-GENE') 1.0
# Now ('pp90rsk', 'I-GENE') 1.0
# Now ('EDXR', 'O') 1.0
# Now ('eliminates', 'O') 2.0
# Now ('brightness', 'O') 2.0
# Now ('toruloides', 'O') 1.0
# Now ('coextracted', 'O') 1.0
# Now ('equilibration', 'O') 1.0
# Now ('HClO4', 'O') 1.0
# Now ('Sarin', 'O') 1.0
# Now ('BBB', 'O') 1.0
# Now ('endosomal', 'O') 1.0
# Now ('calvings', 'O') 1.0
# Now ('Psychological', 'O') 2.0
# Now ('IP', 'O') 2.0
# Now ('CRF1', 'I-GENE') 2.0
# Now ('DMBA', 'O') 1.0
# Now ('Cut', 'O') 1.0
# Now ('Pugh', 'O') 1.0
# Now ('1821', 'O') 1.0
# Now ('dephosphorylates', 'O') 1.0
# Now ('corns', 'O') 1.0
# Now ('Galphai', 'I-GENE') 1.0
# Now ('MTB', 'O') 2.0
# Now ('Directives', 'O') 1.0
# Now ('hmr', 'I-GENE') 1.0
# Now ('PC40', 'O') 1.0
# Now ('wheezy', 'O') 1.0
# Now ('S14', 'I-GENE') 1.0
# Now ('157Gd', 'O') 1.0
# Now ('voltae', 'I-GENE') 1.0
# Now ('m6F6', 'I-GENE') 1.0
# Now ('medicated', 'O') 1.0
# Now ('Histopathologic', 'O') 2.0
# Now ('SFD', 'I-GENE') 1.0
# Now ('milieu', 'O') 1.0
# Now ('eRF1', 'I-GENE') 3.0
# Now ('Rev', 'O') 1.0
# Now ('accord', 'O') 2.0
# Now ('fructose', 'I-GENE') 2.0
# Now ('Gle2p', 'I-GENE') 2.0
# Now ('ultracentrifugation', 'O') 1.0
# Now ('scavenger', 'O') 1.0
# Now ('CCR5', 'I-GENE') 3.0
# Now ('PSMB9', 'I-GENE') 1.0
# Now ('distinguishing', 'O') 2.0
# Now ('Movement', 'O') 2.0
# Now ('FLG', 'O') 1.0
# Now ('cine', 'O') 1.0
# Now ('revisited', 'O') 1.0
# Now ('radiosurgery', 'O') 1.0
# Now ('META', 'O') 1.0
# Now ('Meier', 'O') 1.0
# Now ('urinalysis', 'O') 1.0
# Now ('hygroscopicus', 'I-GENE') 1.0
# Now ('12th', 'O') 2.0
# Now ('Depression', 'O') 1.0
# Now ('earliest', 'O') 4.0
# Now ('mask', 'O') 2.0
# Now ('FHCS', 'O') 1.0
# Now ('incentive', 'O') 1.0
# Now ('Norwegian', 'O') 1.0
# Now ('Efforts', 'O') 2.0
# Now ('candidemia', 'O') 1.0
# Now ('Lu', 'O') 1.0
# Now ('ABF1', 'I-GENE') 1.0
# Now ('clofibrate', 'O') 1.0
# Now ('MSC', 'O') 1.0
# Now ('Outflow', 'O') 1.0
# Now ('Issyk', 'O') 1.0
# Now ('Mcm2', 'I-GENE') 2.0
# Now ('disposition', 'O') 2.0
# Now ('ensis', 'O') 1.0
# Now ('hardness', 'O') 2.0
# Now ('seroconversion', 'O') 3.0
# Now ('craniofacial', 'O') 1.0
# Now ('Arhythmacanthus', 'O') 1.0
# Now ('eutrophus', 'O') 1.0
# Now ('781', 'O') 1.0
# Now ('prospects', 'O') 2.0
# Now ('vHnf1', 'I-GENE') 1.0
# Now ('oligoesters', 'O') 1.0
# Now ('ZFa', 'I-GENE') 1.0
# Now ('Trident', 'I-GENE') 1.0
# Now ('ALVA', 'O') 1.0
# Now ('chromaffin', 'O') 1.0
# Now ('supershifted', 'O') 2.0
# Now ('dF', 'O') 2.0
# Now ('vertebrae', 'O') 4.0
# Now ('CLTPA', 'O') 1.0
# Now ('tryptophanyl', 'I-GENE') 1.0
# Now ('branches', 'O') 3.0
# Now ('herpesvirus', 'I-GENE') 2.0
# Now ('Inventory', 'O') 1.0
# Now ('5G', 'O') 1.0
# Now ('emetic', 'O') 1.0
# Now ('Caco', 'O') 1.0
# Now ('ECA', 'O') 1.0
# Now ('toruloides', 'I-GENE') 1.0
# Now ('Rlm1', 'I-GENE') 3.0
# Now ('P70', 'I-GENE') 1.0
# Now ('Norway', 'O') 2.0
# Now ('PCC6803', 'O') 1.0
# Now ('untransfected', 'O') 1.0
# Now ('fepA', 'I-GENE') 1.0
# Now ('EpoR', 'I-GENE') 1.0
# Now ('AGA', 'O') 1.0
# Now ('sensitizing', 'O') 1.0
# Now ('intracisternal', 'O') 3.0
# Now ('Deglutition', 'O') 1.0
# Now ('exacerbates', 'O') 1.0
# Now ('ventilators', 'O') 2.0
# Now ('Checklist', 'O') 1.0
# Now ('opportunity', 'O') 3.0
# Now ('synchronicity', 'O') 1.0
# Now ('DIssF', 'I-GENE') 1.0
# Now ('alloantibodies', 'O') 1.0
# Now ('Yap1p', 'I-GENE') 2.0
# Now ('Mississippi', 'O') 1.0
# Now ('cardiogenesis', 'O') 1.0
# Now ('building', 'O') 1.0
# Now ('scored', 'O') 2.0
# Now ('sea', 'I-GENE') 1.0
# Now ('homesick', 'O') 1.0
# Now ('E44D', 'O') 1.0
# Now ('pelA', 'I-GENE') 1.0
# Now ('chlorthalidone', 'O') 1.0
# Now ('Staphylococcus', 'I-GENE') 4.0
# Now ('regressive', 'O') 1.0
# Now ('inconspicuous', 'O') 1.0
# Now ('MMRs', 'O') 1.0
# Now ('virginiamycin', 'O') 2.0
# Now ('drs2', 'I-GENE') 1.0
# Now ('NIK', 'O') 1.0
# Now ('hTAFII32', 'I-GENE') 1.0
# Now ('D2Mit1', 'I-GENE') 1.0
# Now ('germ', 'I-GENE') 3.0
# Now ('translatable', 'O') 1.0
# Now ('LCR', 'I-GENE') 3.0
# Now ('hydroxylamine', 'O') 1.0
# Now ('Hypertonic', 'O') 1.0
# Now ('Light', 'O') 2.0
# Now ('alinidine', 'O') 1.0
# Now ('Left', 'O') 2.0
# Now ('accessibility', 'O') 2.0
# Now ('TRE1', 'I-GENE') 1.0
# Now ('semiconductors', 'O') 2.0
# Now ('RING', 'I-GENE') 2.0
# Now ('reconstructing', 'O') 1.0
# Now ('Pallidum', 'O') 1.0
# Now ('A4324', 'O') 1.0
# Now ('Replication', 'O') 1.0
# Now ('embolisms', 'O') 2.0
# Now ('PAC1', 'I-GENE') 1.0
# Now ('widens', 'O') 1.0
# Now ('YAP2', 'I-GENE') 1.0
# Now ('shrimp', 'O') 1.0
# Now ('P7', 'O') 1.0
# Now ('DFak56', 'I-GENE') 1.0
# Now ('Convulsive', 'O') 2.0
# Now ('CAKs', 'I-GENE') 1.0
# Now ('Filter', 'O') 1.0
# Now ('73', 'I-GENE') 1.0
# Now ('Inc', 'O') 1.0
# Now ('settings', 'O') 4.0
# Now ('")', 'O') 4.0
# Now ('preponderance', 'O') 2.0
# Now ('RACLO', 'O') 1.0
# Now ('reciprocally', 'O') 1.0
# Now ('phylogeny', 'O') 1.0
# Now ('cisterna', 'O') 1.0
# Now ('endorsed', 'O') 1.0
# Now ('trabecular', 'O') 3.0
# Now ('poloxamer', 'O') 3.0
# Now ('Tn4451', 'I-GENE') 1.0
# Now ('cif1', 'O') 1.0
# Now ('plexiform', 'O') 1.0
# Now ('Jak2', 'I-GENE') 3.0
# Now ('148', 'O') 4.0
# Now ('mms2', 'I-GENE') 1.0
# Now ('sunscreens', 'O') 1.0
# Now ('ethers', 'O') 1.0
# Now ('thiamine', 'O') 2.0
# Now ('DS', 'O') 1.0
# Now ('megabase', 'O') 1.0
# Now ('paraparesis', 'O') 1.0
# Now ('XLRP', 'O') 1.0
# Now ('CYP11A', 'I-GENE') 1.0
# Now ('neurohumoral', 'O') 1.0
# Now ('propria', 'O') 3.0
# Now ('Hyaluronan', 'O') 1.0
# Now ('3Lys', 'I-GENE') 1.0
# Now ('morphogenetic', 'O') 1.0
# Now ('TAFII250', 'I-GENE') 1.0
# Now ('myristoylation', 'O') 2.0
# Now ('Postop', 'O') 1.0
# Now ('losing', 'O') 1.0
# Now ('debt', 'O') 2.0
# Now ('scenario', 'O') 2.0
# Now ('Possibly', 'O') 1.0
# Now ('epithelioma', 'O') 1.0
# Now ('phosphatidylcholine', 'O') 2.0
# Now ('cGMPase', 'I-GENE') 1.0
# Now ('afterloading', 'O') 1.0
# Now ('Substituting', 'O') 1.0
# Now ('E194A', 'O') 1.0
# Now ('Mas70p', 'I-GENE') 1.0
# Now ('disclosed', 'O') 3.0
# Now ('hHR23', 'I-GENE') 1.0
# Now ('PKNbeta', 'I-GENE') 1.0
# Now ('Rac2', 'I-GENE') 1.0
# Now ('EBPalpha', 'I-GENE') 2.0
# Now ('Ent', 'I-GENE') 1.0
# Now ('vigabatrin', 'O') 1.0
# Now ('Queensland', 'O') 1.0
# Now ('bitten', 'O') 1.0
# Now ('dA', 'O') 3.0
# Now ('mastin', 'I-GENE') 1.0
# Now ('HOG1', 'I-GENE') 2.0
# Now ('conservatively', 'O') 2.0
# Now ('Output', 'O') 1.0
# Now ('hemiacetal', 'O') 1.0
# Now ('H2As', 'I-GENE') 1.0
# Now ('422', 'O') 2.0
# Now ('acidic', 'I-GENE') 1.0
# Now ('Chicken', 'O') 1.0
# Now ('Jkappa', 'I-GENE') 3.0
# Now ('pCIM1', 'O') 1.0
# Now ('RNA15', 'I-GENE') 3.0
# Now ('TAF145', 'I-GENE') 1.0
# Now ('Mlu', 'I-GENE') 1.0
# Now ('IE68', 'I-GENE') 2.0
# Now ('Isoelectric', 'O') 1.0
# Now ('carboxyl', 'I-GENE') 1.0
# Now ('thymus', 'I-GENE') 1.0
# Now ('LEF1', 'I-GENE') 1.0
# Now ('CKII', 'I-GENE') 2.0
# Now ('carboxylesterase', 'I-GENE') 1.0
# Now ('cdk6', 'I-GENE') 2.0
# Now ('Zf', 'O') 1.0
# Now ('NirA', 'I-GENE') 1.0
# Now ('resonances', 'O') 1.0
# Now ('LDEE', 'O') 1.0
# Now ('abscesses', 'O') 1.0
# Now ('tabulated', 'O') 1.0
# Now ('opiate', 'I-GENE') 3.0
# Now ('EPVs', 'O') 1.0
# Now ('sIg', 'I-GENE') 1.0
# Now ('mkh1', 'I-GENE') 1.0
# Now ('official', 'O') 2.0
# Now ('haemolysis', 'O') 1.0
# Now ('transplanting', 'O') 1.0
# Now ('bcd', 'I-GENE') 1.0
# Now ('Alzheimer', 'I-GENE') 1.0
# Now ('Compensatory', 'O') 1.0
# Now ('AC3F1', 'O') 1.0
# Now ('Ralpha', 'I-GENE') 1.0
# Now ('domoic', 'O') 1.0
# Now ('rectus', 'O') 1.0
# Now ('remain', 'O') 4.0
# Now ('RHAL', 'O') 2.0
# Now ('artifact', 'O') 1.0
# Now ('deiodination', 'O') 1.0
# Now ('XII', 'I-GENE') 2.0
# Now ('WFAg', 'I-GENE') 1.0
# Now ('Xa', 'I-GENE') 1.0
# Now ('computation', 'O') 1.0
# Now ('MPS1', 'I-GENE') 2.0
# Now ('Ros', 'O') 1.0
# Now ('stylirostris', 'O') 1.0
# Now ('RCA', 'O') 3.0
# Now ('socioeconomic', 'O') 2.0
# Now ('IIc', 'O') 2.0
# Now ('Asp27', 'O') 1.0
# Now ('cotyledon', 'O') 1.0
# Now ('concensus', 'O') 1.0
# Now ('groE', 'I-GENE') 1.0
# Now ('COL1A2', 'I-GENE') 2.0
# Now ('beaded', 'O') 1.0
# Now ('cosmetic', 'O') 3.0
# Now ('OVAR', 'O') 1.0
# Now ('conductometry', 'O') 1.0
# Now ('sennoside', 'O') 1.0
# Now ('USF2', 'I-GENE') 2.0
# Now ('FlO2', 'O') 1.0
# Now ('carpi', 'O') 1.0
# Now ('Pl', 'O') 1.0
# Now ('microseconds', 'O') 4.0
# Now ('Id3', 'I-GENE') 1.0
# Now ('drawn', 'O') 3.0
# Now ('hyperdynamic', 'O') 1.0
# Now ('gigantic', 'O') 1.0
# Now ('cassette', 'I-GENE') 4.0
# Now ('bulkiness', 'O') 1.0
# Now ('nonperfusion', 'O') 2.0
# Now ('Aotus', 'O') 1.0
# Now ('CD44v', 'I-GENE') 2.0
# Now ('ALCLs', 'O') 1.0
# Now ('nad1', 'I-GENE') 1.0
# Now ('Taussig', 'O') 1.0
# Now ('RE1', 'I-GENE') 1.0
# Now ('tree', 'O') 3.0
# Now ('GMT', 'O') 1.0
# Now ('ERabp1', 'I-GENE') 1.0
# Now ('adrenocortico', 'O') 1.0
# Now ('powdered', 'O') 2.0
# Now ('PHe', 'O') 1.0
# Now ('PRDII', 'O') 1.0
# Now ('worse', 'O') 4.0
# Now ('Nitric', 'O') 1.0
# Now ('198Au', 'O') 1.0
# Now ('damages', 'O') 1.0
# Now ('expectations', 'O') 1.0
# Now ('NM', 'O') 1.0
# Now ('FO', 'O') 1.0
# Now ('CaMV', 'O') 1.0
# Now ('BCs', 'O') 1.0
# Now ('Hauschka', 'O') 1.0
# Now ('establishing', 'O') 4.0
# Now ('p60', 'I-GENE') 2.0
# Now ('electrochemical', 'O') 4.0
# Now ('cables', 'O') 1.0
# Now ('Curing', 'O') 1.0
# Now ('rendered', 'O') 4.0
# Now ('inst', 'O') 1.0
# Now ('MCC', 'I-GENE') 1.0
# Now ('componenents', 'O') 1.0
# Now ('androgenic', 'O') 2.0
# Now ('NOM', 'O') 1.0
# Now ('cLL2', 'I-GENE') 1.0
# Now ('promotor', 'I-GENE') 1.0
# Now ('Thalamotomy', 'O') 1.0
# Now ('rs2', 'I-GENE') 1.0
# Now ('CARP', 'I-GENE') 2.0
# Now ('celiac', 'O') 1.0
# Now ('addressing', 'O') 1.0
# Now ('CLL', 'O') 3.0
# Now ('osteoblasts', 'O') 2.0
# Now ('cystadenoma', 'O') 1.0
# Now ('PMSG', 'I-GENE') 1.0
# Now ('VB', 'O') 1.0
# Now ('SLF', 'I-GENE') 1.0
# Now ('MAdCAM', 'I-GENE') 4.0
# Now ('VZV', 'I-GENE') 2.0
# Now ('stimulation', 'I-GENE') 1.0
# Now ('thermodilution', 'O') 1.0
# Now ('hibernating', 'O') 1.0
# Now ('electroconvulsive', 'O') 4.0
# Now ('superoxide', 'O') 2.0
# Now ('Recording', 'O') 1.0
# Now ('untransformed', 'O') 3.0
# Now ('Karst', 'O') 1.0
# Now ('CPE', 'I-GENE') 1.0
# Now ('overrides', 'O') 1.0
# Now ('B27', 'I-GENE') 1.0
# Now ('Demyelinating', 'O') 1.0
# Now ('W118R', 'O') 1.0
# Now ('boars', 'O') 1.0
# Now ('NIMA', 'I-GENE') 2.0
# Now ('deoxy', 'O') 1.0
# Now ('impairs', 'O') 4.0
# Now ('GBV', 'O') 1.0
# Now ('RalGDS', 'I-GENE') 3.0
# Now ('fungal', 'I-GENE') 2.0
# Now ('Horner', 'O') 1.0
# Now ('Snail', 'O') 1.0
# Now ('oxygenated', 'O') 1.0
# Now ('Manganese', 'O') 1.0
# Now ('Hennebert', 'O') 1.0
# Now ('201Tl', 'O') 4.0
# Now ('cyclohexene', 'O') 1.0
# Now ('gastrostomy', 'O') 1.0
# Now ('p21Cip1', 'I-GENE') 3.0
# Now ('CAD', 'O') 3.0
# Now ('digest', 'O') 1.0
# Now ('Multiresistant', 'O') 1.0
# Now ('Year', 'O') 1.0
# Now ('HYPOTHESIS', 'O') 1.0
# Now ('H2B', 'I-GENE') 1.0
# Now ('haemofiltration', 'O') 1.0
# Now ('lyophilized', 'O') 1.0
# Now ('CD28RE', 'I-GENE') 1.0
# Now ('HPRF', 'O') 1.0
# Now ('GREs', 'O') 1.0
# Now ('vectorcardiographic', 'O') 1.0
# Now ('originated', 'O') 2.0
# Now ('valuation', 'O') 1.0
# Now ('ASAP1', 'I-GENE') 1.0
# Now ('3740', 'O') 1.0
# Now ('PPARs', 'I-GENE') 2.0
# Now ('dysfunctions', 'O') 2.0
# Now ('eminence', 'O') 2.0
# Now ('oligosaccharides', 'O') 1.0
# Now ('wall', 'I-GENE') 1.0
# Now ('Potential', 'O') 3.0
# Now ('followup', 'O') 2.0
# Now ('Holger', 'O') 1.0
# Now ('emitting', 'O') 1.0
# Now ('NMO1', 'I-GENE') 1.0
# Now ('sports', 'O') 1.0
# Now ('Infirmary', 'O') 1.0
# Now ('CPA', 'O') 1.0
# Now ('displaces', 'O') 1.0
# Now ('ammonia', 'I-GENE') 1.0
# Now ('founder', 'O') 1.0
# Now ('LGL', 'O') 2.0
# Now ('761', 'O') 1.0
# Now ('epiHMA', 'O') 1.0
# Now ('labetalol', 'O') 2.0
# Now ('phosphatidic', 'O') 2.0
# Now ('beet', 'O') 2.0
# Now ('endopeptidase', 'O') 1.0
# Now ('gp20', 'I-GENE') 2.0
# Now ('siblings', 'O') 2.0
# Now ('completing', 'O') 1.0
# Now ('complementarity', 'I-GENE') 1.0
# Now ('Blue', 'O') 2.0
# Now ('PN2', 'O') 1.0
# Now ('itch', 'O') 1.0
# Now ('subfraction', 'O') 1.0
# Now ('transregulators', 'O') 1.0
# Now ('pityriasis', 'O') 1.0
# Now ('eventually', 'O') 3.0
# Now ('TS2', 'I-GENE') 1.0
# Now ('CEP', 'O') 1.0
# Now ('rps3', 'I-GENE') 1.0
# Now ('Ini1', 'I-GENE') 1.0
# Now ('NF20', 'O') 1.0
# Now ('Nud1p', 'I-GENE') 1.0
# Now ('cryptosporidia', 'O') 2.0
# Now ('illuminate', 'O') 1.0
# Now ('F219', 'O') 1.0
# Now ('CGGBP', 'I-GENE') 1.0
# Now ('reflection', 'O') 3.0
# Now ('SHPTP1', 'I-GENE') 1.0
# Now ('pentafluorobenzyl', 'O') 1.0
# Now ('Vevey', 'O') 1.0
# Now ('assembling', 'O') 1.0
# Now ('singlecopy', 'O') 1.0
# Now ('Endurance', 'O') 1.0
# Now ('lie', 'O') 3.0
# Now ('Thr161', 'O') 1.0
# Now ('archaeon', 'O') 1.0
# Now ('SL126', 'I-GENE') 1.0
# Now ('EDV', 'O') 2.0
# Now ('nsP4', 'I-GENE') 1.0
# Now ('anorexia', 'O') 4.0
# Now ('higher', 'I-GENE') 1.0
# Now ('Kumar', 'O') 1.0
# Now ('RU486', 'O') 2.0
# Now ('signed', 'O') 1.0
# Now ('rGST', 'I-GENE') 1.0
# Now ('amalgam', 'I-GENE') 1.0
# Now ('confused', 'O') 1.0
# Now ('enhanson', 'I-GENE') 2.0
# Now ('lyophilised', 'O') 1.0
# Now ('JW', 'O') 1.0
# Now ('NeuroD2', 'I-GENE') 4.0
# Now ('alaproclate', 'O') 1.0
# Now ('Emergency', 'O') 1.0
# Now ('orderly', 'O') 2.0
# Now ('trees', 'O') 1.0
# Now ('endotoxin', 'I-GENE') 1.0
# Now ('oxidised', 'O') 1.0
# Now ('prenylation', 'O') 2.0
# Now ('scaling', 'O') 2.0
# Now ('Pbx3', 'I-GENE') 1.0
# Now ('14th', 'O') 1.0
# Now ('flare', 'O') 2.0
# Now ('Debaryomyces', 'O') 1.0
# Now ('CKB', 'I-GENE') 1.0
# Now ('zia', 'I-GENE') 1.0
# Now ('potently', 'O') 2.0
# Now ('immunomodulator', 'O') 1.0
# Now ('pretransplant', 'O') 1.0
# Now ('Days', 'O') 2.0
# Now ('Stress', 'I-GENE') 3.0
# Now ('starts', 'O') 1.0
# Now ('HILL', 'O') 1.0
# Now ('dystrophy', 'I-GENE') 1.0
# Now ('Prague', 'O') 1.0
# Now ('Dalgarno', 'O') 3.0
# Now ('ketones', 'O') 1.0
# Now ('-]/[', 'O') 1.0
# Now ('homeobox', 'O') 1.0
# Now ('32x10', 'O') 1.0
# Now ('transformant', 'O') 1.0
# Now ('CVCC', 'O') 1.0
# Now ('mannitol', 'O') 2.0
# Now ('S6K2', 'I-GENE') 3.0
# Now ('secrete', 'O') 2.0
# Now ('NGF', 'I-GENE') 4.0
# Now ('466', 'O') 1.0
# Now ('dolichol', 'O') 1.0
# Now ('extremity', 'O') 4.0
# Now ('pathologists', 'O') 1.0
# Now ('Helicobacter', 'O') 2.0
# Now ('flexibility', 'O') 1.0
# Now ('postlabel', 'O') 1.0
# Now ('okadaic', 'O') 4.0
# Now ('Phenylephrine', 'O') 1.0
# Now ('polyproteins', 'O') 1.0
# Now ('Vol', 'O') 1.0
# Now ('3b', 'O') 1.0
# Now ('outlet', 'O') 1.0
# Now ('sulbactam', 'O') 1.0
# Now ('Ras2p', 'I-GENE') 1.0
# Now ('reductive', 'O') 1.0
# Now ('reabsorption', 'O') 3.0
# Now ('009', 'O') 1.0
# Now ('cointegrate', 'O') 1.0
# Now ('rifapentine', 'O') 1.0
# Now ('phosphodiester', 'O') 1.0
# Now ('T187A', 'O') 1.0
# Now ('HPRL', 'I-GENE') 1.0
# Now ('SNU', 'O') 1.0
# Now ('TFIIIB', 'I-GENE') 3.0
# Now ('LPH', 'I-GENE') 1.0
# Now ('Borrelia', 'O') 2.0
# Now ('Skeletal', 'O') 2.0
# Now ('Depending', 'O') 2.0
# Now ('XT', 'I-GENE') 1.0
# Now ('prostheses', 'O') 3.0
# Now ('ERP', 'O') 2.0
# Now ('PVS1', 'O') 1.0
# Now ('modA', 'I-GENE') 1.0
# Now ('os', 'O') 2.0
# Now ('Eastern', 'O') 1.0
# Now ('satisfaction', 'O') 2.0
# Now ('cognate', 'I-GENE') 2.0
# Now ('perioral', 'O') 1.0
# Now ('Clintec', 'O') 1.0
# Now ('vasodilatory', 'O') 1.0
# Now ('ionomycin', 'O') 1.0
# Now ('q31', 'O') 2.0
# Now ('CFDN', 'O') 1.0
# Now ('Clinically', 'O') 1.0
# Now ('Ser129', 'O') 1.0
# Now ('octanoic', 'O') 1.0
# Now ('SL11', 'I-GENE') 1.0
# Now ('Cr', 'I-GENE') 1.0
# Now ('PYR', 'I-GENE') 1.0
# Now ('transcallosal', 'O') 1.0
# Now ('PP14', 'I-GENE') 1.0
# Now ('Hisanaga', 'O') 1.0
# Now ('mucocutaneous', 'O') 1.0
# Now ('Diallylnitrosamine', 'O') 1.0
# Now ('sGTH', 'I-GENE') 4.0
# Now ('publications', 'O') 1.0
# Now ('toxaphene', 'O') 1.0
# Now ('cumlations', 'O') 1.0
# Now ('CAPD', 'O') 2.0
# Now ('exacerbated', 'O') 2.0
# Now ('constructing', 'O') 4.0
# Now ('caulinodans', 'O') 1.0
# Now ('myovirus', 'O') 1.0
# Now ('Rinderpest', 'O') 1.0
# Now ('477', 'O') 2.0
# Now ('racemization', 'O') 1.0
# Now ('RNK', 'I-GENE') 2.0
# Now ('d27', 'O') 1.0
# Now ('49', 'I-GENE') 2.0
# Now ('RIBA', 'O') 2.0
# Now ('pedal', 'O') 1.0
# Now ('antinociceptive', 'O') 2.0
# Now ('PTP1C', 'I-GENE') 1.0
# Now ('somatotrophin', 'I-GENE') 1.0
# Now ('Estrogen', 'I-GENE') 1.0
# Now ('auxin', 'O') 2.0
# Now ('qualifications', 'O') 2.0
# Now ('Casablanca', 'O') 1.0
# Now ('K159', 'I-GENE') 1.0
# Now ('asks', 'O') 1.0
# Now ('q25', 'O') 1.0
# Now ('Preimmune', 'I-GENE') 1.0
# Now ('osmoregulatory', 'O') 1.0
# Now ('ALVAC', 'O') 1.0
# Now ('Red', 'O') 2.0
# Now ('cox', 'I-GENE') 1.0
# Now ('479', 'O') 3.0
# Now ('XRD', 'O') 1.0
# Now ('dinitrate', 'O') 2.0
# Now ('Ge', 'O') 1.0
# Now ('Technicon', 'O') 1.0
# Now ('NS2', 'I-GENE') 1.0
# Now ('sarcoplasmic', 'O') 1.0
# Now ('uteroglobin', 'I-GENE') 2.0
# Now ('red', 'I-GENE') 2.0
# Now ('Aplysia', 'I-GENE') 1.0
# Now ('coreceptor', 'O') 2.0
# Now ('Bihar', 'O') 1.0
# Now ('attitude', 'O') 1.0
# Now ('humoral', 'O') 4.0
# Now ('agrB', 'I-GENE') 1.0
# Now ('trichogen', 'O') 1.0
# Now ('Diet', 'O') 3.0
# Now ('cements', 'O') 1.0
# Now ('Voltage', 'I-GENE') 1.0
# Now ('EnA', 'I-GENE') 1.0
# Now ('catheters', 'O') 3.0
# Now ('humanized', 'I-GENE') 1.0
# Now ('television', 'O') 1.0
# Now ('pim', 'I-GENE') 3.0
# Now ('correlative', 'O') 1.0
# Now ('ADM', 'O') 1.0
# Now ('FREJ4', 'O') 1.0
# Now ('Rad3', 'I-GENE') 1.0
# Now ('neurosensory', 'O') 2.0
# Now ('Spring', 'O') 2.0
# Now ('caspases', 'I-GENE') 1.0
# Now ('pygmy', 'O') 1.0
# Now ('modulus', 'O') 2.0
# Now ('neutrophil', 'I-GENE') 3.0
# Now ('LMC', 'O') 1.0
# Now ('microanalysis', 'O') 1.0
# Now ('F1xC57BL', 'O') 1.0
# Now ('MluI', 'I-GENE') 2.0
# Now ('Peripheral', 'O') 3.0
# Now ('STRs', 'O') 1.0
# Now ('straight', 'O') 2.0
# Now ('R277', 'O') 1.0
# Now ('SiO2', 'O') 1.0
# Now ('Cells', 'O') 2.0
# Now ('BD', 'O') 2.0
# Now ('retinol', 'I-GENE') 1.0
# Now ('proxy', 'O') 1.0
# Now ('Employing', 'O') 2.0
# Now ('serines', 'O') 1.0
# Now ('Epitope', 'O') 1.0
# Now ('PLCgamma', 'I-GENE') 2.0
# Now ('Kronstad', 'O') 1.0
# Now ('Coactivation', 'O') 1.0
# Now ('triphenyltetrazolium', 'O') 1.0
# Now ('CI', 'I-GENE') 1.0
# Now ('SRZ', 'I-GENE') 1.0
# Now ('672', 'O') 1.0
# Now ('Symptomatic', 'O') 1.0
# Now ('srd', 'I-GENE') 1.0
# Now ('IQs', 'O') 1.0
# Now ('intraoperative', 'O') 3.0
# Now ('gains', 'O') 2.0
# Now ('Lymphoproliferative', 'O') 1.0
# Now ('baculoviruses', 'O') 4.0
# Now ('pig', 'I-GENE') 1.0
# Now ('prenatal', 'O') 4.0
# Now ('sim', 'I-GENE') 1.0
# Now ('lactalbumin', 'I-GENE') 1.0
# Now ('stereotactically', 'O') 1.0
# Now ('liverwort', 'O') 1.0
# Now ('furin', 'I-GENE') 4.0
# Now ('HMG20', 'I-GENE') 1.0
# Now ('carcinoembryonic', 'I-GENE') 4.0
# Now ('LFA', 'I-GENE') 3.0
# Now ('pat', 'I-GENE') 1.0
# Now ('endotracheal', 'O') 2.0
# Now ('microliters', 'O') 2.0
# Now ('Bifunctionality', 'O') 1.0
# Now ('cpc', 'I-GENE') 3.0
# Now ('NPT', 'I-GENE') 2.0
# Now ('SUP46', 'I-GENE') 1.0
# Now ('AO2', 'O') 1.0
# Now ('Nernst', 'O') 1.0
# Now ('LL', 'O') 1.0
# Now ('nigra', 'O') 2.0
# Now ('chondroitin', 'O') 3.0
# Now ('western', 'O') 4.0
# Now ('crossover', 'O') 3.0
# Now ('CXC', 'I-GENE') 2.0
# Now ('MAZE', 'O') 1.0
# Now ('Thogoto', 'O') 1.0
# Now ('Changing', 'O') 1.0
# Now ('erythroid', 'I-GENE') 3.0
# Now ('intercalated', 'O') 1.0
# Now ('TGEK', 'I-GENE') 1.0
# Now ('TUB4', 'I-GENE') 1.0
# Now ('rasVal12', 'I-GENE') 1.0
# Now ('450', 'I-GENE') 4.0
# Now ('recombined', 'O') 1.0
# Now ('colicin', 'I-GENE') 1.0
# Now ('declamping', 'O') 1.0
# Now ('3736', 'O') 1.0
# Now ('KCS', 'I-GENE') 4.0
# Now ('Novartis', 'O') 1.0
# Now ('scaffold', 'O') 3.0
# Now ('comigrated', 'O') 4.0
# Now ('A3', 'I-GENE') 2.0
# Now ('kd', 'I-GENE') 1.0
# Now ('maturating', 'O') 1.0
# Now ('LSCC', 'O') 1.0
# Now ('criticism', 'O') 2.0
# Now ('polarization', 'O') 3.0
# Now ('CreA', 'I-GENE') 2.0
# Now ('recombinations', 'O') 1.0
# Now ('gyri', 'O') 1.0
# Now ('adrenocorticotropin', 'I-GENE') 1.0
# Now ('1162', 'O') 1.0
# Now ('T45', 'O') 1.0
# Now ('QLMI', 'O') 1.0
# Now ('dephosphorylation', 'O') 4.0
# Now ('80', 'I-GENE') 1.0
# Now ('cooperates', 'O') 2.0
# Now ('86', 'I-GENE') 4.0
# Now ('SNF6', 'I-GENE') 2.0
# Now ('nonhepatic', 'O') 1.0
# Now ('spacers', 'O') 1.0
# Now ('stump', 'O') 1.0
# Now ('APS1', 'I-GENE') 2.0
# Now ('Supplementation', 'O') 1.0
# Now ('Morphometrical', 'O') 1.0
# Now ('Nim', 'O') 1.0
# Now ('XI', 'I-GENE') 3.0
# Now ('researches', 'O') 1.0
# Now ('PNT', 'O') 1.0
# Now ('antispasmodic', 'O') 1.0
# Now ('breathed', 'O') 2.0
# Now ('vagal', 'O') 3.0
# Now ('plating', 'O') 1.0
# Now ('ALS', 'O') 2.0
# Now ('differentiates', 'O') 1.0
# Now ('dyes', 'O') 1.0
# Now ('Rss1p', 'I-GENE') 1.0
# Now ('150K', 'O') 1.0
# Now ('Case', 'O') 2.0
# Now ('sheet', 'O') 1.0
# Now ('3351', 'O') 1.0
# Now ('PTS1R', 'I-GENE') 1.0
# Now ('AL', 'O') 1.0
# Now ('Kishimoto', 'O') 1.0
# Now ('coagulopathic', 'O') 1.0
# Now ('Mobilization', 'O') 1.0
# Now ('Der3p', 'I-GENE') 1.0
# Now ('misdiagnosed', 'O') 1.0
# Now ('1p', 'I-GENE') 1.0
# Now ('Elledge', 'O') 1.0
# Now ('embryofetal', 'O') 2.0
# Now ('Pell', 'O') 1.0
# Now ('interrelation', 'O') 2.0
# Now ('analyzes', 'O') 1.0
# Now ('L18A', 'I-GENE') 1.0
# Now ('Kul', 'O') 1.0
# Now ('methodologically', 'O') 1.0
# Now ('Emeritus', 'O') 1.0
# Now ('regulating', 'I-GENE') 1.0
# Now ('123I', 'O') 2.0
# Now ('SPK', 'O') 2.0
# Now ('UL3', 'I-GENE') 2.0
# Now ('Ntr', 'I-GENE') 1.0
# Now ('opposes', 'O') 1.0
# Now ('Cardiovascular', 'O') 3.0
# Now ('dig2', 'I-GENE') 2.0
# Now ('L18', 'I-GENE') 1.0
# Now ('NP', 'I-GENE') 3.0
# Now ('SPT', 'I-GENE') 1.0
# Now ('AGM', 'I-GENE') 1.0
# Now ('MDA231', 'O') 1.0
# Now ('Biohydrogenation', 'O') 1.0
# Now ('RLF', 'O') 1.0
# Now ('/+', 'O') 2.0
# Now ('qi', 'O') 1.0
# Now ('VirF', 'I-GENE') 1.0
# Now ('Improved', 'O') 2.0
# Now ('medicinal', 'O') 1.0
# Now ('convenient', 'O') 3.0
# Now ('ATX', 'I-GENE') 1.0
# Now ('SMC', 'O') 1.0
# Now ('Gac1', 'I-GENE') 1.0
# Now ('Campomelic', 'O') 1.0
# Now ('phosphonomutase', 'I-GENE') 1.0
# Now ('amplicon', 'O') 1.0
# Now ('chCTCF', 'I-GENE') 1.0
# Now ('LysU', 'I-GENE') 1.0
# Now ('codon', 'I-GENE') 2.0
# Now ('voicing', 'O') 1.0
# Now ('BiP', 'I-GENE') 4.0
# Now ('Kf', 'O') 2.0
# Now ('hSNF5', 'I-GENE') 1.0
# Now ('expired', 'O') 1.0
# Now ('679', 'O') 1.0
# Now ('occlusal', 'O') 2.0
# Now ('Dietetics', 'O') 1.0
# Now ('NOT1', 'I-GENE') 1.0
# Now ('PYK1', 'I-GENE') 1.0
# Now ('42d', 'O') 1.0
# Now ('unphosphorylated', 'O') 2.0
# Now ('PSVT', 'O') 1.0
# Now ('cosinor', 'O') 1.0
# Now ('difficulties', 'O') 4.0
# Now ('click', 'O') 2.0
# Now ('G6PD', 'I-GENE') 2.0
# Now ('defence', 'O') 2.0
# Now ('antipyrine', 'O') 3.0
# Now ('ERabp4', 'I-GENE') 1.0
# Now ('papillae', 'O') 1.0
# Now ('QBMDs', 'O') 1.0
# Now ('quantitatively', 'O') 2.0
# Now ('MutY', 'I-GENE') 2.0
# Now ('lymphograms', 'O') 1.0
# Now ('horizontally', 'O') 1.0
# Now ('elute', 'O') 2.0
# Now ('Posterior', 'I-GENE') 1.0
# Now ('triose', 'I-GENE') 1.0
# Now ('(-.', 'O') 2.0
# Now ('depended', 'O') 2.0
# Now ('GPB', 'I-GENE') 1.0
# Now ('018', 'O') 1.0
# Now ('Korean', 'O') 1.0
# Now ('ecologists', 'O') 1.0
# Now ('ICP35', 'I-GENE') 2.0
# Now ('mxbD', 'I-GENE') 1.0
# Now ('p193', 'I-GENE') 1.0
# Now ('VM', 'O') 2.0
# Now ('525', 'O') 2.0
# Now ('CAS', 'I-GENE') 4.0
# Now ('extemporaneous', 'O') 1.0
# Now ('gauge', 'O') 1.0
# Now ('ranking', 'O') 1.0
# Now ('Arctic', 'O') 2.0
# Now ('wheezing', 'O') 1.0
# Now ('nevadensin', 'O') 2.0
# Now ('Socialization', 'O') 1.0
# Now ('Rhodnius', 'O') 1.0
# Now ('mud', 'O') 1.0
# Now ('Feeding', 'O') 1.0
# Now ('carotene', 'O') 3.0
# Now ('PecS', 'I-GENE') 1.0
# Now ('MCs', 'O') 1.0
# Now ('warming', 'O') 1.0
# Now ('adrenalectomized', 'O') 2.0
# Now ('Kallas', 'O') 1.0
# Now ('succeeded', 'O') 1.0
# Now ('hrpRS', 'I-GENE') 1.0
# Now ('germinal', 'I-GENE') 1.0
# Now ('Cd2', 'O') 1.0
# Now ('fimbrins', 'I-GENE') 1.0
# Now ('notified', 'O') 2.0
# Now ('awareness', 'O') 3.0
# Now ('Step', 'O') 1.0
# Now ('omentum', 'O') 1.0
# Now ('suprapineal', 'O') 1.0
# Now ('dipeptide', 'O') 1.0
# Now ('excitonic', 'O') 1.0
# Now ('withthe', 'O') 1.0
# Now ('rotating', 'O') 1.0
# Now ('git8', 'I-GENE') 1.0
# Now ('Coats', 'O') 1.0
# Now ('mMT', 'I-GENE') 1.0
# Now ('Viral', 'O') 4.0
# Now ('engrailed', 'I-GENE') 2.0
# Now ('incompletely', 'O') 1.0
# Now ('Skp1p', 'I-GENE') 1.0
# Now ('argued', 'O') 1.0
# Now ('Concomitant', 'O') 1.0
# Now ('1118', 'O') 1.0
# Now ('Rep68', 'I-GENE') 3.0
# Now ('Haemostasis', 'O') 1.0
# Now ('UB', 'O') 1.0
# Now ('underscribed', 'O') 1.0
# Now ('GH3', 'O') 2.0
# Now ('Polysorbate', 'O') 1.0
# Now ('MLS1', 'I-GENE') 2.0
# Now ('Marynen', 'O') 1.0
# Now ('peers', 'O') 1.0
# Now ('Chaperones', 'O') 1.0
# Now ('curable', 'O') 1.0
# Now ('KEFGK', 'O') 1.0
# Now ('E44D', 'I-GENE') 1.0
# Now ('Ser44', 'O') 1.0
# Now ('alpha2c', 'I-GENE') 1.0
# Now ('SMV', 'O') 1.0
# Now ('Pi', 'I-GENE') 1.0
# Now ('autoproteolysis', 'O') 1.0
# Now ('secretions', 'O') 2.0
# Now ('fly', 'O') 1.0
# Now ('tetramers', 'I-GENE') 2.0
# Now ('TCCCCT', 'O') 1.0
# Now ('lactic', 'O') 3.0
# Now ('technics', 'O') 2.0
# Now ('INF', 'I-GENE') 1.0
# Now ('CreI', 'I-GENE') 1.0
# Now ('myotonic', 'I-GENE') 1.0
# Now ('5738', 'O') 1.0
# Now ('decamer', 'O') 2.0
# Now ('polyglycolic', 'O') 1.0
# Now ('bathophenanthroline', 'O') 1.0
# Now ('GABPalpha', 'I-GENE') 3.0
# Now ('Interdomain', 'O') 1.0
# Now ('furoviruses', 'O') 1.0
# Now ('hydroxyantipyrine', 'O') 1.0
# Now ('TRAP', 'I-GENE') 4.0
# Now ('emmetropia', 'O') 1.0
# Now ('BI', 'I-GENE') 2.0
# Now ('Elementary', 'O') 1.0
# Now ('processing', 'I-GENE') 1.0
# Now ('cytadherence', 'I-GENE') 1.0
# Now ('T84', 'I-GENE') 2.0
# Now ('adjustments', 'O') 2.0
# Now ('reflexly', 'O') 2.0
# Now ('Adapromine', 'O') 1.0
# Now ('complements', 'O') 4.0
# Now ('MAT', 'I-GENE') 3.0
# Now ('Chemicals', 'O') 1.0
# Now ('biased', 'O') 2.0
# Now ('gap', 'O') 2.0
# Now ('Canalith', 'O') 1.0
# Now ('AF154055', 'I-GENE') 1.0
# Now ('icosahaedral', 'O') 1.0
# Now ('benz', 'O') 1.0
# Now ('13', 'I-GENE') 2.0
# Now ('micromelias', 'O') 1.0
# Now ('plantar', 'O') 2.0
# Now ('Professor', 'O') 1.0
# Now ('inspiration', 'O') 2.0
# Now ('485', 'I-GENE') 1.0
# Now ('clozapine', 'O') 1.0
# Now ('ZNF274', 'I-GENE') 1.0
# Now ('tyrR', 'O') 1.0
# Now ('TFIIF', 'I-GENE') 2.0
# Now ('persistently', 'O') 1.0
# Now ('ice', 'O') 2.0
# Now ('oestrus', 'O') 1.0
# Now ('hD2', 'I-GENE') 1.0
# Now ('Ng', 'I-GENE') 1.0
# Now ('dams', 'O') 3.0
# Now ('appropriately', 'O') 2.0
# Now ('accessible', 'O') 4.0
# Now ('Attack', 'O') 1.0
# Now ('Texas', 'O') 1.0
# Now ('BP1', 'I-GENE') 4.0
# Now ('a3', 'O') 2.0
# Now ('serostatus', 'O') 1.0
# Now ('apoB17', 'I-GENE') 1.0
# Now ('australiensis', 'O') 1.0
# Now ('041', 'O') 1.0
# Now ('dien', 'O') 1.0
# Now ('containment', 'O') 1.0
# Now ('cobA', 'I-GENE') 1.0
# Now ('RTKs', 'I-GENE') 1.0
# Now ('224', 'O') 1.0
# Now ('262', 'O') 1.0
# Now ('hammerhead', 'O') 1.0
# Now ('androsterone', 'O') 2.0
# Now ('FGD1', 'I-GENE') 1.0
# Now ('acyclovir', 'O') 2.0
# Now ('incorrectly', 'O') 1.0
# Now ('dysuria', 'O') 2.0
# Now ('uterus', 'O') 4.0
# Now ('dying', 'O') 3.0
# Now ('failing', 'O') 2.0
# Now ('G12V', 'I-GENE') 1.0
# Now ('coincides', 'O') 2.0
# Now ('u', 'O') 2.0
# Now ('74', 'I-GENE') 1.0
# Now ('2Db', 'O') 1.0
# Now ('rami', 'O') 1.0
# Now ('IE72', 'I-GENE') 1.0
# Now ('lipid', 'I-GENE') 1.0
# Now ('dihydrolipoyl', 'I-GENE') 1.0
# Now ('E2H1', 'O') 1.0
# Now ('Adjustment', 'O') 2.0
# Now ('deleting', 'O') 2.0
# Now ('XL', 'I-GENE') 1.0
# Now ('Amadoriopines', 'O') 1.0
# Now ('Rex', 'O') 1.0
# Now ('dopa', 'I-GENE') 1.0
# Now ('reacting', 'O') 3.0
# Now ('flows', 'O') 2.0
# Now ('Rts1p', 'I-GENE') 1.0
# Now ('pacemaker', 'O') 1.0
# Now ('hominis', 'O') 2.0
# Now ('ascorbic', 'O') 3.0
# Now ('pessary', 'O') 1.0
# Now ('FGF8b', 'I-GENE') 1.0
# Now ('transcobalamin', 'I-GENE') 1.0
# Now ('191044', 'O') 1.0
# Now ('piritramide', 'O') 1.0
# Now ('Micrococcus', 'I-GENE') 1.0
# Now ('Tyr497', 'O') 1.0
# Now ('SIN1', 'I-GENE') 1.0
# Now ('burgdorferi', 'O') 1.0
# Now ('NPROSP', 'I-GENE') 1.0
# Now ('crsA1', 'I-GENE') 1.0
# Now ('Fermentation', 'O') 1.0
# Now ('Soman', 'O') 1.0
# Now ('ve', 'O') 1.0
# Now ('microC', 'O') 4.0
# Now ('arteriovenous', 'O') 3.0
# Now ('SOS1', 'I-GENE') 2.0
# Now ('videogame', 'O') 1.0
# Now ('desmethylangolensin', 'O') 1.0
# Now ('Gi', 'I-GENE') 1.0
# Now ('GXGKST', 'O') 1.0
# Now ('preferences', 'O') 4.0
# Now ('straws', 'O') 1.0
# Now ('Kristofferson', 'O') 1.0
# Now ('eosinophilic', 'O') 2.0
# Now ('guanyl', 'O') 1.0
# Now ('insoluble', 'O') 2.0
# Now ('234', 'O') 1.0
# Now ('Dawood', 'O') 1.0
# Now ('emitted', 'O') 1.0
# Now ('ENV', 'I-GENE') 2.0
# Now ('Agrobacterium', 'O') 2.0
# Now ('startpoint', 'O') 1.0
# Now ('relieved', 'O') 2.0
# Now ('caretakers', 'O') 1.0
# Now ('chloralose', 'O') 4.0
# Now ('Campylobacter', 'O') 2.0
# Now ('But', 'O') 3.0
# Now ('Positive', 'O') 4.0
# Now ('Id1', 'I-GENE') 3.0
# Now ('Pyp3', 'I-GENE') 1.0
# Now ('occupationally', 'O') 2.0
# Now ('LIFR', 'I-GENE') 2.0
# Now ('contracting', 'O') 2.0
# Now ('Panama', 'O') 1.0
# Now ('Superose', 'O') 1.0
# Now ('arthritogenic', 'O') 1.0
# Now ('heterophile', 'O') 1.0
# Now ('amniocentesis', 'O') 2.0
# Now ('32D', 'O') 3.0
# Now ('retest', 'O') 2.0
# Now ('L4', 'O') 1.0
# Now ('brachioplasty', 'O') 1.0
# Now ('pyrR', 'I-GENE') 1.0
# Now ('Qualitatively', 'O') 1.0
# Now ('convlusion', 'O') 1.0
# Now ('skp1', 'I-GENE') 1.0
# Now ('Disability', 'O') 1.0
# Now ('Nck', 'I-GENE') 3.0
# Now ('170K', 'O') 1.0
# Now ('158', 'O') 1.0
# Now ('RIHA', 'O') 1.0
# Now ('DPM', 'I-GENE') 1.0
# Now ('telSMN', 'I-GENE') 2.0
# Now ('GH', 'O') 1.0
# Now ('Cytochrome', 'I-GENE') 1.0
# Now ('muscarinic', 'I-GENE') 4.0
# Now ('Diffusion', 'O') 1.0
# Now ('CGP', 'I-GENE') 1.0
# Now ('phentolamine', 'O') 1.0
# Now ('Resources', 'O') 1.0
# Now ('USF1', 'I-GENE') 1.0
# Now ('."', 'O') 3.0
# Now ('plate', 'I-GENE') 1.0
# Now ('M1281', 'O') 1.0
# Now ('562', 'O') 2.0
# Now ('ubiquinone', 'I-GENE') 2.0
# Now ('Tilmicosin', 'O') 1.0
# Now ('glycolate', 'I-GENE') 1.0
# Now ('orf221', 'I-GENE') 1.0
# Now ('NheI', 'I-GENE') 1.0
# Now ('parB', 'I-GENE') 1.0
# Now ('spirometry', 'O') 4.0
# Now ('SF3b', 'I-GENE') 1.0
# Now ('object', 'O') 4.0
# Now ('displaying', 'O') 4.0
# Now ('hyponatremia', 'O') 1.0
# Now ('FCN', 'O') 1.0
# Now ('243', 'O') 4.0
# Now ('immunodeficit', 'O') 1.0
# Now ('triazeno', 'O') 1.0
# Now ('octreotide', 'O') 1.0
# Now ('reticulocyte', 'O') 2.0
# Now ('bFcgamma2R', 'I-GENE') 1.0
# Now ('cascades', 'I-GENE') 1.0
# Now ('dhfr', 'I-GENE') 1.0
# Now ('PTF', 'I-GENE') 3.0
# Now ('AAPBD', 'O') 1.0
# Now ('epididymal', 'O') 3.0
# Now ('tmk', 'I-GENE') 2.0
# Now ('DSF', 'O') 2.0
# Now ('interpersonal', 'O') 2.0
# Now ('Raji', 'O') 3.0
# Now ('narL', 'I-GENE') 1.0
# Now ('brightly', 'O') 1.0
# Now ('Antipyretic', 'O') 1.0
# Now ('HSI', 'O') 1.0
# Now ('neuronal', 'I-GENE') 2.0
# Now ('Sensing', 'O') 1.0
# Now ('ceramics', 'O') 2.0
# Now ('Methyllevamisole', 'O') 1.0
# Now ('note', 'O') 3.0
# Now ('enterolactone', 'O') 1.0
# Now ('XIII', 'O') 1.0
# Now ('RGS6', 'I-GENE') 1.0
# Now ('pVK102', 'O') 1.0
# Now ('industrial', 'O') 3.0
# Now ('FHR2', 'I-GENE') 1.0
# Now ('roughly', 'O') 2.0
# Now ('CYP3A', 'I-GENE') 1.0
# Now ('QS', 'O') 2.0
# Now ('invertebrate', 'O') 2.0
# Now ('foregoing', 'O') 1.0
# Now ('annually', 'O') 1.0
# Now ('2h', 'I-GENE') 2.0
# Now ('unexpectedly', 'O') 1.0
# Now ('CBA', 'O') 3.0
# Now ('PPIase', 'I-GENE') 1.0
# Now ('p21Val', 'I-GENE') 1.0
# Now ('colistin', 'O') 1.0
# Now ('protamine', 'I-GENE') 1.0
# Now (')-,', 'O') 1.0
# Now ('auto', 'O') 2.0
# Now ('MTD', 'O') 2.0
# Now ('STZ', 'O') 1.0
# Now ('Citrullus', 'O') 1.0
# Now ('BVDV', 'O') 2.0
# Now ('myometrial', 'O') 1.0
# Now ('transparent', 'O') 4.0
# Now ('Mac1', 'I-GENE') 1.0
# Now ('stimulator', 'O') 3.0
# Now ('Tn5422', 'I-GENE') 1.0
# Now ('nesting', 'O') 1.0
# Now ('pahangi', 'I-GENE') 1.0
# Now ('apoA', 'I-GENE') 1.0
# Now ('4RE', 'I-GENE') 1.0
# Now ('ERV1', 'I-GENE') 1.0
# Now ('ApxII', 'I-GENE') 1.0
# Now ('quadriplegia', 'O') 1.0
# Now ('Rak', 'I-GENE') 4.0
# Now ('redistributed', 'O') 1.0
# Now ('MMI', 'I-GENE') 1.0
# Now ('Vitamin', 'O') 2.0
# Now ('Acetabular', 'O') 1.0
# Now ('OF5', 'I-GENE') 2.0
# Now ('masse', 'O') 1.0
# Now ('psychometric', 'O') 3.0
# Now ('MLA', 'O') 1.0
# Now ('fowls', 'O') 1.0
# Now ('URA1', 'I-GENE') 1.0
# Now ('anastomoses', 'O') 1.0
# Now ('Rn', 'O') 1.0
# Now ('cystectomy', 'O') 1.0
# Now ('179', 'O') 4.0
# Now ('pseudorandom', 'O') 1.0
# Now ('fear', 'O') 2.0
# Now ('3T2', 'O') 2.0
# Now ('canis', 'I-GENE') 1.0
# Now ('PBDs', 'O') 1.0
# Now ('cohabitation', 'O') 2.0
# Now ('Polymyxin', 'O') 1.0
# Now ('Spo11p', 'I-GENE') 1.0
# Now ('BFB', 'O') 1.0
# Now ('51344', 'O') 1.0
# Now ('implication', 'O') 3.0
# Now ('filaments', 'I-GENE') 2.0
# Now ('resolvases', 'I-GENE') 1.0
# Now ('fauna', 'O') 1.0
# Now ('TATAA', 'I-GENE') 1.0
# Now ('convenience', 'O') 2.0
# Now ('gp85', 'I-GENE') 1.0
# Now ('FIRO', 'O') 1.0
# Now ('Thermus', 'O') 1.0
# Now ('PnCG', 'O') 1.0
# Now ('waveforms', 'O') 4.0
# Now ('presequences', 'O') 1.0
# Now ('inverse', 'O') 4.0
# Now ('Cbf3', 'I-GENE') 1.0
# Now ('Coxiella', 'O') 3.0
# Now ('Fine', 'O') 2.0
# Now ('cytocentrifuge', 'O') 2.0
# Now ('sickling', 'O') 1.0
# Now ('gp15', 'I-GENE') 1.0
# Now ('Galphai1', 'I-GENE') 1.0
# Now ('phenoxy', 'O') 1.0
# Now ('SSS1', 'I-GENE') 1.0
# Now ('78C1', 'O') 2.0
# Now ('confirms', 'O') 4.0
# Now ('Ad12', 'I-GENE') 1.0
# Now ('WHO', 'O') 2.0
# Now ('ergometry', 'O') 1.0
# Now ('Patienten', 'O') 1.0
# Now ('factorial', 'O') 1.0
# Now ('thromboses', 'O') 1.0
# Now ('coregulatory', 'O') 1.0
# Now ('CCAATC', 'O') 1.0
# Now ('arborization', 'O') 1.0
# Now ('E2R', 'I-GENE') 1.0
# Now ('macro', 'O') 1.0
# Now ('unc', 'I-GENE') 2.0
# Now ('Klenow', 'I-GENE') 1.0
# Now ('Fshb', 'I-GENE') 1.0
# Now ('middle', 'I-GENE') 4.0
# Now ('detectability', 'O') 1.0
# Now ('wollastoni', 'O') 1.0
# Now ('anserina', 'O') 1.0
# Now ('purpuratus', 'O') 2.0
# Now ('UASINO', 'O') 1.0
# Now ('permeabilized', 'O') 1.0
# Now ('Tg', 'I-GENE') 1.0
# Now ('institutions', 'O') 3.0
# Now ('Nordette', 'O') 1.0
# Now ('Pao2', 'O') 1.0
# Now ('CYP3A23', 'I-GENE') 1.0
# Now ('ATCC11105', 'O') 1.0
# Now ('RPE65', 'I-GENE') 1.0
# Now ('Extracellular', 'I-GENE') 1.0
# Now ('hydroxyindole', 'O') 1.0
# Now ('brainscintigraphy', 'O') 1.0
# Now ('F3R', 'I-GENE') 1.0
# Now ('686', 'O') 1.0
# Now ('Light', 'I-GENE') 1.0
# Now ('tans', 'O') 1.0
# Now ('m7GpppN', 'O') 1.0
# Now ('moulting', 'O') 1.0
# Now ('5322', 'O') 1.0
# Now ('3D', 'O') 3.0
# Now ('SP6', 'O') 1.0
# Now ('FK1012', 'O') 2.0
# Now ('Sites', 'O') 1.0
# Now ('VCR', 'O') 2.0
# Now ('complete', 'I-GENE') 3.0
# Now ('1gamma', 'I-GENE') 2.0
# Now ('MOPP', 'O') 2.0
# Now ('Theory', 'O') 1.0
# Now ('linarin', 'O') 1.0
# Now ('Imai', 'O') 1.0
# Now ('achievement', 'O') 1.0
# Now ('MuLVs', 'O') 1.0
# Now ('Pentium', 'O') 1.0
# Now ('flutamide', 'O') 1.0
# Now ('Tyrosine', 'I-GENE') 1.0
# Now ('cryomicroscopy', 'O') 1.0
# Now ('rap1', 'I-GENE') 1.0
# Now ('HPK1', 'I-GENE') 3.0
# Now ('PSD2', 'I-GENE') 1.0
# Now ('CIATT', 'O') 1.0
# Now ('mMIWC', 'I-GENE') 1.0
# Now ('Backer', 'O') 1.0
# Now ('divalent', 'O') 1.0
# Now ('scoring', 'O') 1.0
# Now ('zippers', 'O') 4.0
# Now ('notch', 'I-GENE') 1.0
# Now ('acetylglucosaminyltransferase', 'I-GENE') 3.0
# Now ('dimethylsulphate', 'O') 1.0
# Now ('IIIB', 'I-GENE') 2.0
# Now ('p72syk', 'I-GENE') 1.0
# Now ('ILVF', 'O') 2.0
# Now ('3852', 'O') 2.0
# Now ('NOA', 'O') 1.0
# Now ('hydrocortisone', 'O') 3.0
# Now ('AB004534', 'I-GENE') 1.0
# Now ('Diazepam', 'O') 2.0
# Now ('permeation', 'O') 1.0
# Now ('stannous', 'O') 2.0
# Now ('tablets', 'O') 2.0
# Now ('electromyographic', 'O') 1.0
# Now ('demonstrable', 'O') 2.0
# Now ('hamartoma', 'O') 1.0
# Now ('Vasoactive', 'I-GENE') 1.0
# Now ('iso', 'I-GENE') 1.0
# Now ('halogenobenzo', 'O') 1.0
# Now ('FMISO', 'O') 1.0
# Now ('guanosine', 'I-GENE') 1.0
# Now ('SET', 'O') 3.0
# Now ('ORF2a', 'I-GENE') 1.0
# Now ('Huang', 'O') 1.0
# Now ('insemination', 'O') 1.0
# Now ('disagnosis', 'O') 1.0
# Now ('fluorescens', 'O') 2.0
# Now ('Tyr0', 'I-GENE') 1.0
# Now ('curly', 'O') 1.0
# Now ('streptococci', 'O') 2.0
# Now ('684', 'O') 1.0
# Now ('operates', 'O') 1.0
# Now ('nontransformed', 'O') 2.0
# Now ('Checkpoint', 'O') 1.0
# Now ('460', 'O') 2.0
# Now ('ptO2', 'O') 2.0
# Now ('stalk', 'O') 1.0
# Now ('Mobility', 'O') 2.0
# Now ('DAF', 'I-GENE') 2.0
# Now ('peritumorous', 'O') 1.0
# Now ('1977', 'O') 4.0
# Now ('bid', 'O') 1.0
# Now ('weigh', 'O') 1.0
# Now ('trachelectomy', 'O') 1.0
# Now ('Catheter', 'O') 1.0
# Now ('550', 'O') 1.0
# Now ('hermaphrodite', 'O') 1.0
# Now ('neo', 'O') 3.0
# Now ('synapsins', 'I-GENE') 1.0
# Now ('mimicry', 'O') 1.0
# Now ('Acquired', 'O') 2.0
# Now ('groove', 'I-GENE') 1.0
# Now ('triiodothyronine', 'O') 3.0
# Now ('IUCD', 'O') 1.0
# Now ('propeptide', 'O') 1.0
# Now ('PDF', 'O') 1.0
# Now ('420', 'O') 1.0
# Now ('CYP3A2', 'I-GENE') 2.0
# Now ('mesenchyme', 'O') 1.0
# Now ('spinal', 'I-GENE') 1.0
# Now ('perindopril', 'O') 1.0
# Now ('ipiO', 'I-GENE') 1.0
# Now ('whatever', 'O') 2.0
# Now ('Arm', 'O') 1.0
# Now ('seg', 'O') 1.0
# Now ('chaperonin', 'I-GENE') 3.0
# Now ('supravalvular', 'O') 1.0
# Now ('Inactivation', 'O') 4.0
# Now ('bacteriophages', 'O') 2.0
# Now ('CDPDeltaCR1', 'I-GENE') 1.0
# Now ('1881', 'O') 1.0
# Now ('RNL', 'O') 1.0
# Now ('HBSAG', 'I-GENE') 1.0
# Now ('sm', 'O') 1.0
# Now ('441', 'O') 1.0
# Now ('glutamic', 'I-GENE') 2.0
# Now ('Vibramycin', 'O') 1.0
# Now ('Line', 'O') 2.0
# Now ('significative', 'O') 2.0
# Now ('B5', 'I-GENE') 1.0
# Now ('Felix', 'O') 1.0
# Now ('SSP', 'I-GENE') 1.0
# Now ('ISA', 'O') 2.0
# Now ('polydispersity', 'O') 1.0
# Now ('appendages', 'O') 2.0
# Now ('MbO2', 'O') 1.0
# Now ('dated', 'O') 1.0
# Now ('Spo0F', 'I-GENE') 1.0
# Now ('newt', 'O') 2.0
# Now ('severalfold', 'O') 1.0
# Now ('hrpZ', 'I-GENE') 1.0
# Now ('RGS12', 'I-GENE') 1.0
# Now ('C27', 'O') 1.0
# Now ('Deregulation', 'O') 1.0
# Now ('Automatic', 'O') 1.0
# Now ('0017', 'O') 1.0
# Now ('heparin', 'I-GENE') 3.0
# Now ('proteobacterial', 'O') 1.0
# Now ('arm', 'I-GENE') 1.0
# Now ('Mot3', 'I-GENE') 1.0
# Now ('ePTFE', 'O') 1.0
# Now ('LNX', 'I-GENE') 2.0
# Now ('variance', 'O') 4.0
# Now ('trivirgatus', 'O') 1.0
# Now ('Lysozyme', 'I-GENE') 1.0
# Now ('dissolved', 'O') 1.0
# Now ('alternation', 'O') 1.0
# Now ('SOPs', 'O') 1.0
# Now ('LINES', 'O') 1.0
# Now ('IRper', 'O') 4.0
# Now ('DGF', 'O') 1.0
# Now ('PAG', 'O') 1.0
# Now ('anabolic', 'O') 2.0
# Now ('invJ', 'I-GENE') 1.0
# Now ('bimolecular', 'O') 1.0
# Now ('inter', 'O') 3.0
# Now ('edulis', 'O') 1.0
# Now ('essex', 'O') 1.0
# Now ('clorgyline', 'O') 1.0
# Now ('hallucis', 'O') 1.0
# Now ('acetylases', 'I-GENE') 1.0
# Now ('leukocyte', 'I-GENE') 2.0
# Now ('covariable', 'O') 1.0
# Now ('tracts', 'O') 1.0
# Now ('.-', 'O') 4.0
# Now ('mdr', 'I-GENE') 1.0
# Now ('amine', 'I-GENE') 1.0
# Now ('artefact', 'O') 1.0
# Now ('zygotic', 'O') 1.0
# Now ('What', 'O') 4.0
# Now ('abiotic', 'O') 1.0
# Now ('SvO2', 'O') 1.0
# Now ('SFV', 'I-GENE') 1.0
# Now ('TFIIB', 'I-GENE') 4.0
# Now ('dAK', 'I-GENE') 1.0
# Now ('XYL1', 'I-GENE') 1.0
# Now ('nmhC5', 'I-GENE') 1.0
# Now ('concern', 'O') 4.0
# Now ('Presence', 'O') 1.0
# Now ('Biliary', 'O') 1.0
# Now ('nondiabetics', 'O') 2.0
# Now ('CD4', 'O') 1.0
# Now ('triosephosphate', 'I-GENE') 2.0
# Now ('Complex', 'I-GENE') 1.0
# Now ('rrn5', 'I-GENE') 1.0
# Now ('cholangiography', 'O') 1.0
# Now ('combines', 'O') 1.0
# Now ('x', 'I-GENE') 3.0
# Now ('dusky', 'O') 1.0
# Now ('Epigenetic', 'O') 1.0
# Now ('2b', 'O') 3.0
# Now ('I22', 'O') 1.0
# Now ('Survey', 'O') 3.0
# Now ('enrollment', 'O') 1.0
# Now ('Proteinuria', 'O') 2.0
# Now ('rickettsiae', 'O') 1.0
# Now ('microcapsules', 'O') 1.0
# Now ('fimbrial', 'O') 1.0
# Now ('favor', 'O') 1.0
# Now ('hematoma', 'O') 2.0
# Now ('ended', 'O') 1.0
# Now ('inoculum', 'O') 3.0
# Now ('aquaporins', 'I-GENE') 1.0
# Now ('nitrate', 'I-GENE') 3.0
# Now ('AML1', 'I-GENE') 3.0
# Now ('calphostin', 'O') 2.0
# Now ('EHV', 'O') 3.0
# Now ('ps', 'I-GENE') 2.0
# Now ('rectum', 'O') 3.0
# Now ('JPEG', 'O') 1.0
# Now ('DE3', 'O') 3.0
# Now ('Spc42p', 'I-GENE') 2.0
# Now ('maedi', 'O') 1.0
# Now ('dosages', 'O') 4.0
# Now ('088', 'O') 1.0
# Now ('drastic', 'O') 2.0
# Now ('P116', 'O') 1.0
# Now ('Malaria', 'O') 2.0
# Now ('Lg', 'I-GENE') 1.0
# Now ('V3', 'I-GENE') 4.0
# Now ('exercising', 'O') 1.0
# Now ('Eph', 'I-GENE') 1.0
# Now ('sweat', 'O') 1.0
# Now ('R235E', 'O') 1.0
# Now ('parturition', 'O') 2.0
# Now ('eUSF', 'I-GENE') 2.0
# Now ('ITAMs', 'O') 1.0
# Now ('TMV', 'I-GENE') 1.0
# Now ('immunoassays', 'O') 2.0
# Now ('Oscilloscope', 'O') 1.0
# Now ('MC29', 'O') 2.0
# Now ('lipoproteins', 'O') 4.0
# Now ('QTc', 'O') 1.0
# Now ('Thr', 'I-GENE') 2.0
# Now ('critique', 'O') 1.0
# Now ('topa', 'I-GENE') 1.0
# Now ('racemate', 'O') 1.0
# Now ('P13', 'O') 1.0
# Now ('MA', 'O') 4.0
# Now ('RPS30A', 'I-GENE') 1.0
# Now ('SOX9', 'I-GENE') 1.0
# Now ('chorion', 'O') 1.0
# Now ('Bailey', 'O') 1.0
# Now ('C8', 'O') 1.0
# Now ('Adduction', 'O') 1.0
# Now ('bilignost', 'O') 1.0
# Now ('ICS', 'I-GENE') 2.0
# Now ('decay', 'I-GENE') 1.0
# Now ('isocaloric', 'O') 1.0
# Now ('Pt', 'I-GENE') 1.0
# Now ('waiting', 'O') 1.0
# Now ('permeability', 'I-GENE') 1.0
# Now ('rigid', 'O') 1.0
# Now ('granddaughter', 'O') 1.0
# Now ('mediators', 'O') 3.0
# Now ('gingival', 'O') 3.0
# Now ('escapes', 'O') 1.0
# Now ('GenBankTM', 'O') 1.0
# Now ('HSPs', 'I-GENE') 1.0
# Now ('IE110', 'I-GENE') 4.0
# Now ('extensibility', 'O') 2.0
# Now ('Sestamibi', 'O') 1.0
# Now ('Repression', 'O') 2.0
# Now ('hnRNPs', 'I-GENE') 1.0
# Now ('miniature', 'O') 2.0
# Now ('criminal', 'O') 1.0
# Now ('IRA', 'I-GENE') 1.0
# Now ('Persistence', 'O') 1.0
# Now ('Q10', 'O') 3.0
# Now ('noninfarct', 'O') 1.0
# Now ('edelfosine', 'O') 1.0
# Now ('VNTR', 'O') 1.0
# Now ('cisterns', 'O') 1.0
# Now ('EIAV', 'I-GENE') 2.0
# Now ('ulcerans', 'O') 1.0
# Now ('AcFP875', 'I-GENE') 1.0
# Now ('ductal', 'O') 2.0
# Now ('rice', 'I-GENE') 2.0
# Now ('Hoxa3', 'I-GENE') 1.0
# Now ('726', 'O') 2.0
# Now ('territory', 'O') 2.0
# Now ('CHIP28', 'I-GENE') 1.0
# Now ('MRSAs', 'O') 1.0
# Now ('nonenlarging', 'O') 1.0
# Now ('Rigid', 'O') 1.0
# Now ('clopamide', 'O') 1.0
# Now ('adrenoreceptors', 'O') 1.0
# Now ('glucamine', 'O') 1.0
# Now ('sulphide', 'O') 1.0
# Now ('converged', 'O') 1.0
# Now ('ethyloxymethylimidazol', 'O') 1.0
# Now ('Lobb', 'O') 1.0
# Now ('exofacial', 'O') 2.0
# Now ('Ac', 'O') 1.0
# Now ('learn', 'O') 1.0
# Now ('481', 'O') 2.0
# Now ('POG1', 'I-GENE') 1.0
# Now ('stocks', 'O') 1.0
# Now ('RasV12', 'I-GENE') 1.0
# Now ('precordial', 'O') 2.0
# Now ('diagonal', 'O') 2.0
# Now ('FLAIR', 'O') 1.0
# Now ('suction', 'O') 1.0
# Now ('clam', 'O') 1.0
# Now ('sow', 'O') 1.0
# Now ('Vv', 'O') 1.0
# Now ('polyolefin', 'O') 1.0
# Now ('OBLA', 'O') 2.0
# Now ('macaque', 'O') 1.0
# Now ('Paw', 'O') 1.0
# Now ('JT', 'O') 1.0
# Now ('C31', 'O') 1.0
# Now ('septi', 'O') 1.0
# Now ('pAL618', 'O') 1.0
# Now ('karyogamy', 'O') 1.0
# Now ('V25', 'O') 1.0
# Now ('i2', 'I-GENE') 1.0
# Now ('acyl', 'O') 1.0
# Now ('eg', 'O') 2.0
# Now ('FVVLNLQ', 'O') 1.0
# Now ('intein', 'I-GENE') 2.0
# Now ('BPVs', 'O') 1.0
# Now ('atoms', 'O') 4.0
# Now ('CE2', 'O') 3.0
# Now ('mineralization', 'O') 4.0
# Now ('malarias', 'O') 1.0
# Now ('UAS2', 'I-GENE') 1.0
# Now ('Atherosclerosis', 'O') 1.0
# Now ('Systemic', 'O') 4.0
# Now ('cereus', 'O') 2.0
# Now ('synchronizing', 'O') 2.0
# Now ('Pappl', 'O') 1.0
# Now ('sweep', 'O') 2.0
# Now ('yAP180A', 'I-GENE') 1.0
# Now ('drink', 'O') 1.0
# Now ('kedougou', 'O') 1.0
# Now ('bulges', 'O') 1.0
# Now ('Marek', 'I-GENE') 1.0
# Now ('Nramp', 'I-GENE') 2.0
# Now ('Looking', 'O') 1.0
# Now ('Transactivation', 'O') 3.0
# Now ('110K', 'O') 1.0
# Now ('coping', 'O') 1.0
# Now ('composites', 'O') 2.0
# Now ('Sudomoina', 'O') 1.0
# Now ('ABI', 'O') 1.0
# Now ('derail', 'O') 1.0
# Now ('Zorbax', 'O') 1.0
# Now ('Suppressive', 'O') 1.0
# Now ('unfavourable', 'O') 2.0
# Now ('amelgenesis', 'O') 1.0
# Now ('alcR', 'I-GENE') 2.0
# Now ('eclampsia', 'O') 1.0
# Now ('maloclusions', 'O') 1.0
# Now ('autoradiographic', 'O') 1.0
# Now ('Equine', 'O') 1.0
# Now ('segmentation', 'O') 4.0
# Now ('chiefly', 'O') 2.0
# Now ('Abstracts', 'O') 2.0
# Now ('psychosocial', 'O') 2.0
# Now ('PR3', 'I-GENE') 1.0
# Now ('rhein', 'O') 1.0
# Now ('rostral', 'O') 3.0
# Now ('GLUT4', 'I-GENE') 3.0
# Now ('172', 'O') 3.0
# Now ('fasciculations', 'O') 1.0
# Now ('wedge', 'O') 1.0
# Now ('tagging', 'O') 1.0
# Now ('normotensive', 'O') 3.0
# Now ('PTPase', 'I-GENE') 1.0
# Now ('F2771', 'I-GENE') 1.0
# Now ('azithromycin', 'O') 1.0
# Now ('palsy', 'O') 2.0
# Now ('tegument', 'O') 1.0
# Now ('HSP', 'I-GENE') 1.0
# Now ('RSV', 'O') 1.0
# Now ('A84', 'O') 1.0
# Now ('Chronotherapeutics', 'O') 1.0
# Now ('Wellcome', 'O') 1.0
# Now ('microprocessor', 'O') 1.0
# Now ('diathermy', 'O') 1.0
# Now ('T2G4T', 'I-GENE') 1.0
# Now ('Propagation', 'O') 1.0
# Now ('DPOAE', 'O') 2.0
# Now ('preinitiation', 'O') 3.0
# Now ('mds1', 'I-GENE') 2.0
# Now ('493', 'O') 1.0
# Now ('Kss1', 'I-GENE') 1.0
# Now ('photoperiod', 'O') 1.0
# Now ('Alanine', 'I-GENE') 2.0
# Now ('Histiocytic', 'O') 1.0
# Now ('DSPP', 'I-GENE') 1.0
# Now ('GRKRKSP', 'O') 1.0
# Now ('saprophytic', 'O') 1.0
# Now ('spot', 'O') 3.0
# Now ('PCPH', 'I-GENE') 1.0
# Now ('mesoblastic', 'O') 1.0
# Now ('Midge', 'O') 1.0
# Now ('returning', 'O') 2.0
# Now ('immunohistochemistry', 'O') 2.0
# Now ('COR', 'I-GENE') 1.0
# Now ('execution', 'O') 1.0
# Now ('Delta84', 'O') 1.0
# Now ('E37G', 'I-GENE') 1.0
# Now ('booster', 'O') 2.0
# Now ('ALG', 'I-GENE') 4.0
# Now ('Sec31A', 'I-GENE') 1.0
# Now ('soap', 'O') 2.0
# Now ('L12', 'O') 2.0
# Now ('lichenoides', 'O') 1.0
# Now ('Orientation', 'O') 1.0
# Now ('Elk1', 'I-GENE') 2.0
# Now ('Fluoroquinolones', 'O') 1.0
# Now ('PD', 'O') 3.0
# Now ('pancreozymin', 'I-GENE') 1.0
# Now ('2866', 'O') 1.0
# Now ('Stereotactic', 'O') 1.0
# Now ('unnecessary', 'O') 2.0
# Now ('VTs', 'O') 3.0
# Now ('offspring', 'O') 2.0
# Now ('innovation', 'O') 1.0
# Now ('hemoclip', 'O') 1.0
# Now ('swi4', 'I-GENE') 1.0
# Now ('Defective', 'O') 1.0
# Now ('scope', 'O') 1.0
# Now ('Erythroid', 'O') 1.0
# Now ('intrastriatal', 'O') 1.0
# Now ('corepressors', 'O') 1.0
# Now ('thromboxane', 'I-GENE') 4.0
# Now ('HTK', 'O') 1.0
# Now ('ergometer', 'O') 2.0
# Now ('choose', 'O') 1.0
# Now ('Flavonoids', 'O') 1.0
# Now ('450e', 'I-GENE') 1.0
# Now ('ADA', 'I-GENE') 2.0
# Now ('EMB', 'O') 1.0
# Now ('dCCC', 'O') 1.0
# Now ('Oct4', 'I-GENE') 1.0
# Now ('Mnt', 'I-GENE') 2.0
# Now ('Saxony', 'O') 1.0
# Now ('rbcL', 'I-GENE') 2.0
# Now ('historical', 'O') 4.0
# Now ('Me', 'O') 1.0
# Now ('GTTA', 'O') 1.0
# Now ('Temperature', 'O') 2.0
# Now ('KLP', 'I-GENE') 1.0
# Now ('Gonadotropin', 'I-GENE') 1.0
# Now ('vertigo', 'O') 1.0
# Now ('Ser64', 'O') 1.0
# Now ('betaI', 'I-GENE') 1.0
# Now ('cauliflower', 'O') 1.0
# Now ('pJM1', 'O') 1.0
# Now ('MKS', 'I-GENE') 1.0
# Now ('reconsidered', 'O') 2.0
# Now ('kcal', 'O') 2.0
# Now ('sufficiently', 'O') 1.0
# Now ('glyceraldehyde', 'I-GENE') 1.0
# Now ('SGFsp', 'O') 1.0
# Now ('7A2', 'O') 1.0
# Now ('2500', 'O') 1.0
# Now ('(.', 'O') 4.0
# Now ('simvastatin', 'O') 3.0
# Now ('recN', 'I-GENE') 1.0
# Now ('mPAP', 'O') 1.0
# Now ('promotorless', 'O') 1.0
# Now ('typhoid', 'O') 2.0
# Now ('DZ', 'O') 1.0
# Now ('Poor', 'O') 1.0
# Now ('201', 'I-GENE') 1.0
# Now ('pine', 'O') 2.0
# Now ('TRAIL', 'I-GENE') 3.0
# Now ('counseling', 'O') 2.0
# Now ('germanica', 'I-GENE') 1.0
# Now ('Arrest', 'O') 1.0
# Now ('OMeRNA', 'O') 1.0
# Now ('HS3D', 'I-GENE') 1.0
# Now ('moieties', 'O') 1.0
# Now ('synaptically', 'O') 1.0
# Now ('Myelosis', 'O') 1.0
# Now ('epiphyseal', 'O') 2.0
# Now ('XAB1', 'I-GENE') 1.0
# Now ('emphasising', 'O') 1.0
# Now ('Framingham', 'O') 2.0
# Now ('SREs', 'O') 1.0
# Now ('068', 'O') 1.0
# Now ('Saurer', 'O') 1.0
# Now ('GM701', 'O') 1.0
# Now ('Vienna', 'O') 1.0
# Now ('BOCS', 'O') 1.0
# Now ('latencies', 'O') 3.0
# Now ('hypothyroid', 'O') 1.0
# Now ('Darby', 'O') 2.0
# Now ('Lycopersicon', 'O') 1.0
# Now ('inelastic', 'O') 1.0
# Now ('slide', 'O') 3.0
# Now ('kernels', 'O') 1.0
# Now ('metallothionein', 'I-GENE') 3.0
# Now ('G12V', 'O') 1.0
# Now ('Kurzydlowski', 'O') 1.0
# Now ('URE', 'O') 2.0
# Now ('receptive', 'O') 1.0
# Now ('mI', 'O') 3.0
# Now ('NBP', 'O') 2.0
# Now ('651', 'O') 1.0
# Now ('Angiography', 'O') 2.0
# Now ('RC3', 'I-GENE') 3.0
# Now ('Referred', 'O') 1.0
# Now ('Mg', 'I-GENE') 1.0
# Now ('brk', 'I-GENE') 2.0
# Now ('circuits', 'O') 1.0
# Now ('parasitemia', 'O') 2.0
# Now ('firemen', 'O') 1.0
# Now ('8216', 'O') 1.0
# Now ('cast', 'O') 2.0
# Now ('degreesC', 'O') 2.0
# Now ('Zealand', 'O') 3.0
# Now ('100', 'I-GENE') 2.0
# Now ('CeCAT', 'O') 1.0
# Now ('Healthcare', 'O') 1.0
# Now ('518', 'O') 3.0
# Now ('Lymphocytes', 'O') 1.0
# Now ('flashed', 'O') 1.0
# Now ('edges', 'O') 1.0
# Now ('practices', 'O') 1.0
# Now ('Rho1p', 'I-GENE') 2.0
# Now ('afferent', 'O') 4.0
# Now ('Abf1', 'I-GENE') 2.0
# Now ('CD95L', 'I-GENE') 1.0
# Now ('dyad', 'O') 4.0
# Now ('Phosphatidylinositol', 'I-GENE') 1.0
# Now ('nAChR', 'I-GENE') 1.0
# Now ('attrition', 'O') 1.0
# Now ('quarters', 'O') 1.0
# Now ('sieve', 'O') 1.0
# Now ('suturing', 'O') 1.0
# Now ('K294', 'O') 1.0
# Now ('helps', 'O') 1.0
# Now ('HTP', 'O') 2.0
# Now ('reticulin', 'I-GENE') 2.0
# Now ('Wee1', 'O') 1.0
# Now ('orifice', 'O') 1.0
# Now ('][', 'O') 2.0
# Now ('Mus', 'O') 2.0
# Now ('2556', 'O') 1.0
# Now ('tectum', 'O') 2.0
# Now ('medians', 'O') 1.0
# Now ('ELT', 'I-GENE') 1.0
# Now ('Pseudocontact', 'O') 1.0
# Now ('derepress', 'O') 1.0
# Now ('curls', 'O') 1.0
# Now ('Respondents', 'O') 1.0
# Now ('wearing', 'O') 1.0
# Now ('1O2', 'O') 4.0
# Now ('noncholestatic', 'O') 1.0
# Now ('C6H6', 'O') 1.0
# Now ('leukotriene', 'O') 2.0
# Now ('cardiomegaly', 'O') 1.0
# Now ('myelodysplastic', 'O') 1.0
# Now ('NaBr', 'O') 2.0
# Now ('H2A2', 'I-GENE') 1.0
# Now ('naja', 'O') 2.0
# Now ('ketoconazole', 'O') 3.0
# Now ('deer', 'O') 1.0
# Now ('biotype', 'O') 2.0
# Now ('Competitive', 'O') 2.0
# Now ('Ringer', 'O') 1.0
# Now ('approximately', 'I-GENE') 2.0
# Now ('Prostate', 'I-GENE') 2.0
# Now ('MFA2', 'I-GENE') 1.0
# Now ('dissociative', 'O') 1.0
# Now ('PRDII', 'I-GENE') 2.0
# Now ('buccal', 'O') 1.0
# Now ('BMPs', 'I-GENE') 1.0
# Now ('Verbal', 'O') 1.0
# Now ('bioassay', 'O') 2.0
# Now ('RGS', 'I-GENE') 2.0
# Now ('enoximone', 'O') 1.0
# Now ('Dianthus', 'O') 1.0
# Now ('Diabetes', 'O') 1.0
# Now ('say', 'O') 1.0
# Now ('guillotine', 'O') 1.0
# Now ('capacitor', 'O') 1.0
# Now ('UAC', 'I-GENE') 1.0
# Now ('xenobiotic', 'O') 2.0
# Now ('Sex', 'O') 3.0
# Now ('SIP', 'O') 3.0
# Now ('Y88S', 'I-GENE') 1.0
# Now ('Sop1p', 'I-GENE') 2.0
# Now ('1744', 'O') 1.0
# Now ('iohexol', 'O') 1.0
# Now ('Merosin', 'I-GENE') 1.0
# Now ('COX12', 'I-GENE') 1.0
# Now ('zebrafish', 'I-GENE') 1.0
# ...
# Now ('Endogenous', 'O') 2.0
# Now ('polyoxyethylene', 'O') 1.0
# Now ('INTERVENTION', 'O') 1.0
# Now ('TATAA', 'O') 2.0
# Now ('(-)', 'I-GENE') 1.0
# Now ('doubled', 'O') 2.0
# Now ('breads', 'O') 1.0
# Now ('immunophilin', 'I-GENE') 2.0
# Now ('stressing', 'O') 1.0
# Now ('analytes', 'O') 1.0
# Now ('miliary', 'O') 2.0
# Now ('SF2149', 'O') 1.0
# Now ('betweent', 'O') 1.0
# Now ('luteinized', 'O') 1.0
# Now ('uncontrollable', 'O') 1.0
# Now ('Method', 'O') 1.0
# Now ('farnesyl', 'O') 1.0
# Now ('phyla', 'O') 1.0
# Now ('CPS', 'I-GENE') 2.0
# Now ('OLB', 'O') 2.0
# Now ('lovastatin', 'O') 2.0
# Now ('p33cdk2', 'I-GENE') 1.0
# Now ('DdPTPa', 'I-GENE') 1.0
# Now ('lymphoid', 'I-GENE') 3.0
# Now ('p45', 'I-GENE') 3.0
# Now ('phosphotryptic', 'O') 1.0
# Now ('athletes', 'O') 1.0
# Now ('rifampicin', 'O') 1.0
# Now (')/', 'I-GENE') 4.0
# Now ('metallopeptidases', 'I-GENE') 1.0
# Now ('KS1', 'I-GENE') 1.0
# Now ('amanitin', 'I-GENE') 2.0
# Now ('etr', 'I-GENE') 1.0
# Now ('Arf', 'I-GENE') 1.0
# Now ('split', 'O') 3.0
# Now ('CDC14', 'I-GENE') 1.0
# Now ('ALS', 'I-GENE') 1.0
# Now ('melancholic', 'O') 1.0
# Now ('microchromosome', 'O') 1.0
# Now ('apressin', 'O') 1.0
# Now ('biventricular', 'O') 1.0
# Now ('Bitter', 'O') 1.0
# Now ('proteases', 'I-GENE') 3.0
# Now ('Fv', 'I-GENE') 2.0
# Now ('pigeons', 'O') 1.0
# Now ('Radiolabeled', 'O') 1.0
# Now ('proportional', 'O') 3.0
# Now ('Optimal', 'O') 2.0
# Now ('dawson', 'O') 1.0
# Now ('E2F3', 'I-GENE') 1.0
# Now ('Inherent', 'O') 1.0
# Now ('transducer', 'O') 3.0
# Now ('declining', 'O') 2.0
# Now ('consideration', 'O') 4.0
# Now ('kinesin', 'I-GENE') 2.0
# Now ('focuses', 'O') 1.0
# Now ('MacLeod', 'O') 1.0
# Now ('flour', 'O') 3.0
# Now ('intakes', 'O') 3.0
# Now ('overproduced', 'O') 3.0
# Now ('IBS1', 'I-GENE') 1.0
# Now ('PGL', 'O') 1.0
# Now ('gangrene', 'O') 2.0
# Now ('labyrinthotomy', 'O') 1.0
# Now ('Fpgs', 'I-GENE') 1.0
# Now ('antidepressant', 'O') 2.0
# Now ('phenols', 'O') 1.0
# Now ('exogenous', 'I-GENE') 1.0
# Now ('EMSAs', 'O') 2.0
# Now ('MDV', 'O') 4.0
# Now ('Sacchromyces', 'I-GENE') 1.0
# Now ('4603', 'O') 1.0
# Now ('volleys', 'O') 1.0
# Now ('G5', 'O') 1.0
# Now ('pancreaticobiliary', 'O') 2.0
# Now ('ATG1', 'I-GENE') 1.0
# Now ('immunogenic', 'O') 3.0
# Now ('trimer', 'I-GENE') 2.0
# Now ('Rv', 'O') 1.0
# Now ('Og4C3', 'I-GENE') 2.0
# Now ('prudent', 'O') 1.0
# Now ('dimerization', 'I-GENE') 1.0
# Now ('lamellipodia', 'O') 1.0
# Now ('aminorex', 'O') 1.0
# Now ('placentae', 'O') 2.0
# Now ('1928', 'O') 1.0
# Now ('JDV', 'O') 1.0
# Now ('nucleocytoplasmic', 'O') 1.0
# Now ('film', 'O') 3.0
# Now ('peroneal', 'O') 2.0
# Now ('Varicella', 'I-GENE') 1.0
# Now ('couldn', 'O') 1.0
# Now ('Mn', 'I-GENE') 1.0
# Now ('peppermint', 'O') 1.0
# Now ('polynucleotides', 'O') 1.0
# Now ('Transcripts', 'O') 4.0
# Now ('FY', 'O') 1.0
# Now ('midcell', 'O') 1.0
# Now ('Igf2', 'I-GENE') 2.0
# Now ('anchor', 'I-GENE') 4.0
# Now ('wethers', 'O') 1.0
# Now ('Tg', 'O') 1.0
# Now ('PhLOP1', 'I-GENE') 1.0
# Now ('OIA', 'O') 1.0
# Now ('rpL7a', 'I-GENE') 1.0
# Now ('286', 'O') 1.0
# Now ('sarcomere', 'O') 1.0
# Now ('discern', 'O') 1.0
# Now ('BRDG1', 'I-GENE') 1.0
# Now ('NHE3', 'I-GENE') 2.0
# Now ('exact', 'O') 3.0
# Now ('FTF', 'I-GENE') 1.0
# Now ('SMMHC', 'I-GENE') 1.0
# Now ('noticeable', 'O') 1.0
# Now ('reporters', 'O') 2.0
# Now ('siroheme', 'O') 1.0
# Now ('HCK', 'I-GENE') 1.0
# Now ('CPY', 'I-GENE') 1.0
# Now ('SB3', 'O') 1.0
# Now ('Stromelysin', 'I-GENE') 1.0
# Now ('felt', 'O') 1.0
# Now ('vibrating', 'O') 1.0
# Now ('ovomucoid', 'I-GENE') 1.0
# Now ('spasmolytic', 'O') 1.0
# Now ('Pittsburgh', 'O') 1.0
# Now ('Resolution', 'O') 1.0
# Now ('biotechnology', 'O') 2.0
# Now ('angioplasty', 'O') 4.0
# Now ('Lebanon', 'O') 1.0
# Now ('Femoral', 'O') 1.0
# Now ('p230', 'I-GENE') 2.0
# Now ('dream', 'O') 3.0
# Now ('contraindicated', 'O') 1.0
# Now ('CRL3', 'I-GENE') 1.0
# Now ('martensitic', 'O') 1.0
# Now ('casebook', 'O') 1.0
# Now ('40th', 'O') 1.0
# Now ('rubidium', 'O') 2.0
# Now ('oranges', 'O') 1.0
# Now ('minigene', 'O') 1.0
# Now ('10654', 'O') 1.0
# Now ('Sec', 'I-GENE') 2.0
# Now ('Prognosis', 'O') 2.0
# Now ('HEFT1', 'I-GENE') 1.0
# Now ('difluorophenyl', 'O') 1.0
# Now ('Statistics', 'O') 2.0
# Now ('Dirofilaria', 'I-GENE') 1.0
# Now ('crystallographic', 'O') 3.0
# Now ('p21WAF1', 'I-GENE') 2.0
# Now ('Dox', 'O') 1.0
# Now ('polytetrafluoroethylene', 'O') 1.0
# Now ('depressing', 'O') 1.0
# Now ('CARbeta', 'I-GENE') 1.0
# Now ('surfactant', 'I-GENE') 1.0
# Now ('percentiles', 'O') 1.0
# Now ('Multifunctional', 'I-GENE') 1.0
# Now ('craniocaudal', 'O') 1.0
# Now ('Clipping', 'O') 1.0
# Now ('Val', 'I-GENE') 1.0
# Now ('tocopherol', 'O') 2.0
# Now ('mossy', 'O') 1.0
# Now ('ERG', 'O') 1.0
# Now ('tilting', 'O') 1.0
# Now ('IMV', 'O') 1.0
# Now ('RRMs', 'O') 1.0
# Now ('Ume5p', 'I-GENE') 1.0
# Now ('repetitive', 'I-GENE') 1.0
# Now ('easy', 'O') 4.0
# Now ('PTPS', 'I-GENE') 1.0
# Now ('Men', 'O') 1.0
# Now ('RHD', 'O') 2.0
# Now ('rhythmometrically', 'O') 1.0
# Now ('MDS', 'O') 2.0
# Now ('rocuronium', 'O') 1.0
# Now ('ano', 'O') 1.0
# Now ('Ackerman', 'O') 1.0
# Now ('blister', 'O') 4.0
# Now ('ruminantium', 'O') 1.0
# Now ('Sample', 'O') 1.0
# Now ('russelli', 'O') 1.0
# Now ('eIF4GI', 'I-GENE') 2.0
# Now ('Tesla', 'O') 2.0
# Now ('TACTAAC', 'O') 1.0
# Now ('topoisomers', 'O') 3.0
# Now ('Let', 'O') 1.0
# Now ('P69', 'O') 1.0
# Now ('PSP', 'O') 1.0
# Now ('DAF16', 'I-GENE') 1.0
# Now ('ricotta', 'O') 1.0
# Now ('Netherlands', 'O') 1.0
# Now ('emulsions', 'O') 4.0
# Now ('1356', 'O') 2.0
# Now ('DDC', 'O') 1.0
# Now ('collimation', 'O') 1.0
# Now ('apoprotein', 'I-GENE') 1.0
# Now ('co', 'I-GENE') 1.0
# Now ('Tyr705', 'O') 1.0
# Now ('PAK', 'I-GENE') 3.0
# Now ('operators', 'I-GENE') 1.0
# Now ('measurable', 'O') 3.0
# Now ('repressible', 'O') 1.0
# Now ('tryptic', 'O') 2.0
# Now ('doxycycline', 'O') 2.0
# Now ('SalI', 'I-GENE') 3.0
# Now ('PDGFbetaR', 'I-GENE') 1.0
# Now ('identifiability', 'O') 1.0
# Now ('attractiveness', 'O') 1.0
# Now ('TPK2', 'I-GENE') 1.0
# Now ('pitting', 'O') 1.0
# Now ('Tendon', 'O') 1.0
# Now ('tegumental', 'O') 1.0
# Now ('1110', 'O') 1.0
# Now ('cysB', 'I-GENE') 1.0
# Now ('South', 'O') 3.0
# Now ('16690', 'O') 1.0
# Now ('alphavirus', 'I-GENE') 1.0
# Now ('mtDNA', 'O') 4.0
# Now ('heritability', 'O') 1.0
# Now ('dPn', 'O') 1.0
# Now ('VHB', 'O') 1.0
# Now ('Hoxb1', 'I-GENE') 1.0
# Now ('GSK', 'I-GENE') 1.0
# Now ('Secretion', 'O') 2.0
# Now ('Stimulation', 'O') 4.0
# Now ('innervating', 'O') 2.0
# Now ('CCAAAT', 'I-GENE') 1.0
# Now ('uninfluenced', 'O') 2.0
# Now ('ethyloxymethyl', 'O') 1.0
# Now ('515', 'I-GENE') 2.0
# Now ('latest', 'O') 2.0
# Now ('Rattus', 'O') 2.0
# Now ('flt', 'I-GENE') 1.0
# Now ('aphakic', 'O') 1.0
# Now ('Viruses', 'O') 1.0
# Now ('MMT', 'O') 1.0
# Now ('dioxin', 'I-GENE') 1.0
# Now ('Ypt53p', 'I-GENE') 1.0
# Now ('neoplasm', 'O') 2.0
# Now ('Mcd4p', 'I-GENE') 1.0
# Now ('Potentiation', 'O') 1.0
# Now ('discomfort', 'O') 1.0
# Now ('ACGCGT', 'O') 1.0
# Now ('Lace', 'I-GENE') 1.0
# Now ('stock', 'O') 3.0
# Now ('perturbation', 'O') 2.0
# Now ('bottles', 'O') 1.0
# Now ('CAL', 'O') 3.0
# Now ('FliT', 'I-GENE') 1.0
# Now ('Cln3p', 'I-GENE') 1.0
# Now ('epicardial', 'O') 2.0
# Now ('well', 'I-GENE') 1.0
# Now ('Antisense', 'O') 1.0
# Now ('steep', 'O') 2.0
# Now ('rubripes', 'O') 1.0
# Now ('1031', 'O') 1.0
# Now ('Jack', 'I-GENE') 1.0
# Now ('homesickness', 'O') 1.0
# Now ('Microvessels', 'O') 1.0
# Now ('densitometer', 'O') 1.0
# Now ('KIFB', 'I-GENE') 1.0
# Now ('racemize', 'O') 1.0
# Now ('280', 'O') 3.0
# Now ('neurolysis', 'O') 1.0
# Now ('political', 'O') 1.0
# Now ('traversing', 'O') 1.0
# Now ('connective', 'I-GENE') 1.0
# Now ('Ulp2', 'I-GENE') 1.0
# Now ('Scanning', 'O') 3.0
# Now ('seeks', 'O') 1.0
# Now ('planes', 'O') 1.0
# Now ('Selenastrum', 'O') 1.0
# Now ('reflexometry', 'O') 1.0
# Now ('FIA', 'O') 1.0
# Now ('Moscow', 'O') 3.0
# Now ('diphosphatase', 'I-GENE') 1.0
# Now ('eIF4G', 'I-GENE') 1.0
# Now ('Mharp', 'I-GENE') 1.0
# Now ('reducing', 'I-GENE') 1.0
# Now ('(,)', 'O') 1.0
# Now ('chromogenic', 'O') 1.0
# Now ('mud', 'I-GENE') 1.0
# Now ('KA', 'O') 2.0
# Now ('599', 'O') 1.0
# Now ('Berglund', 'O') 1.0
# Now ('digiprogenin', 'O') 1.0
# Now ('CDR2', 'I-GENE') 1.0
# Now ('TIS10', 'I-GENE') 1.0
# Now ('methoxyisobutylisonitrile', 'O') 1.0
# Now ('APTT', 'O') 1.0
# Now ('Spectroscopy', 'O') 1.0
# Now ('Trichinella', 'O') 1.0
# Now ('Transabdominal', 'O') 1.0
# Now ('olivocochlear', 'O') 1.0
# Now ('hexanucleotide', 'O') 4.0
# Now ('Endometrial', 'O') 1.0
# Now ('AMPK', 'I-GENE') 1.0
# Now ('ERRalpha1', 'I-GENE') 3.0
# Now ('hepatocellular', 'O') 3.0
# Now ('MABP', 'O') 2.0
# Now ('CP2', 'I-GENE') 1.0
# Now ('phenformin', 'O') 3.0
# Now ('poxvirus', 'O') 1.0
# Now ('SSM1b', 'I-GENE') 2.0
# Now ('pigments', 'O') 1.0
# Now ('spouse', 'O') 3.0
# Now ('haematological', 'O') 2.0
# Now ('sublingual', 'O') 1.0
# Now ('tablespoons', 'O') 1.0
# Now ('diiodosalicylate', 'O') 1.0
# Now ('DSM319', 'O') 1.0
# Now ('Successful', 'O') 4.0
# Now ('SS', 'I-GENE') 2.0
# Now ('Azithromycin', 'O') 1.0
# Now ('cotE', 'I-GENE') 1.0
# Now ('freeze', 'O') 2.0
# Now ('achalasia', 'O') 1.0
# Now ('skipping', 'O') 2.0
# Now ('Melatonin', 'O') 1.0
# Now ('RS2', 'O') 1.0
# Now ('Tn5', 'I-GENE') 1.0
# Now ('hereinafter', 'O') 1.0
# Now ('saccades', 'O') 3.0
# Now ('CD19', 'I-GENE') 1.0
# Now ('1137', 'O') 1.0
# Now ('Percentage', 'O') 1.0
# Now ('AMD', 'O') 1.0
# Now ('Than', 'O') 1.0
# Now ('shrinkage', 'O') 2.0
# Now ('postpartum', 'O') 3.0
# Now ('explants', 'O') 2.0
# Now ('3rd', 'O') 2.0
# Now ('enhancers', 'O') 4.0
# Now ('electromobility', 'O') 2.0
# Now ('Pause', 'O') 1.0
# Now ('bZIP1', 'O') 1.0
# Now ('croup', 'O') 1.0
# Now ('620', 'I-GENE') 1.0
# Now ('Normocapnic', 'O') 1.0
# Now ('purkinje', 'O') 1.0
# Now ('HTLV', 'I-GENE') 3.0
# Now ('paralyzed', 'O') 2.0
# Now ('alveoli', 'O') 3.0
# Now ('abrogates', 'O') 1.0
# Now ('Rhizobium', 'I-GENE') 1.0
# Now ('SCA', 'I-GENE') 1.0
# Now ('Bianca', 'O') 1.0
# Now ('CASH', 'I-GENE') 1.0
# Now ('multichannel', 'O') 2.0
# Now ('DBMS', 'O') 1.0
# Now ('autoreceptor', 'O') 1.0
# Now ('Nitrogen', 'O') 2.0
# Now ('tail', 'I-GENE') 1.0
# Now ('ENV', 'O') 2.0
# Now ('Protease', 'O') 1.0
# Now ('l', 'I-GENE') 3.0
# Now ('nonsyndromic', 'O') 1.0
# Now ('Underlying', 'O') 1.0
# Now ('ABPs', 'I-GENE') 1.0
# Now ('SWI5', 'I-GENE') 2.0
# Now ('Amikacin', 'O') 4.0
# Now ('fundus', 'O') 1.0
# Now ('p73pct1', 'I-GENE') 1.0
# Now ('rim15Delta', 'I-GENE') 1.0
# Now ('initiator', 'I-GENE') 1.0
# Now ('pTyr317', 'I-GENE') 1.0
# Now ('IL8', 'I-GENE') 2.0
# Now ('rescreening', 'O') 1.0
# Now ('GA2', 'I-GENE') 1.0
# Now ('nanos', 'I-GENE') 1.0
# Now ('y', 'O') 3.0
# Now ('concentric', 'O') 2.0
# Now ('TRP', 'O') 2.0
# Now ('s6', 'I-GENE') 1.0
# Now ('bilobar', 'O') 1.0
# Now ('Angina', 'O') 2.0
# Now ('periphery', 'O') 2.0
# Now ('silk', 'I-GENE') 1.0
# Now ('thyroglobulin', 'I-GENE') 4.0
# Now ('EP4', 'I-GENE') 1.0
# Now ('Geisler', 'O') 1.0
# Now ('hypo', 'O') 1.0
# Now ('SIE', 'I-GENE') 1.0
# Now ('Complete', 'O') 4.0
# Now ('predetermining', 'O') 1.0
# Now ('Coliphage', 'I-GENE') 1.0
# Now ('Tryptic', 'O') 1.0
# Now ('ASTA', 'O') 1.0
# Now ('chimeras', 'O') 4.0
# Now ('his7', 'I-GENE') 1.0
# Now ('nosocomial', 'O') 1.0
# Now ('mating', 'I-GENE') 3.0
# Now ('dentistry', 'O') 1.0
# Now ('performing', 'O') 2.0
# Now ('chemiluminescence', 'O') 4.0
# Now ('market', 'O') 3.0
# Now ('vasospasms', 'O') 1.0
# Now ('parallels', 'O') 2.0
# Now ('radium', 'O') 2.0
# Now ('expression', 'I-GENE') 2.0
# Now ('CeCAT', 'I-GENE') 1.0
# Now ('antigenic', 'I-GENE') 1.0
# Now ('Rabbit', 'O') 1.0
# Now ('bH', 'I-GENE') 1.0
# Now ('athetoid', 'O') 1.0
# Now ('hypopituitarism', 'O') 1.0
# Now ('Actins', 'I-GENE') 1.0
# Now ('nondiapausing', 'O') 1.0
# Now ('angiolymphoid', 'O') 1.0
# Now ('member', 'I-GENE') 4.0
# Now ('LAF', 'I-GENE') 2.0
# Now ('six', 'I-GENE') 1.0
# Now ('mer', 'I-GENE') 1.0
# Now ('701', 'O') 1.0
# Now ('MEKK3', 'I-GENE') 2.0
# Now ('HAM', 'O') 1.0
# Now ('acquire', 'O') 3.0
# Now ('datasets', 'O') 1.0
# Now ('D1A', 'I-GENE') 2.0
# Now ('thymic', 'I-GENE') 1.0
# Now ('semiquantitatively', 'O') 1.0
# Now ('triphosphatase', 'I-GENE') 3.0
# Now ('School', 'O') 1.0
# Now ('interrupt', 'O') 1.0
# Now ('Immunologic', 'O') 1.0
# Now ('extrapolated', 'O') 4.0
# Now ('sable', 'I-GENE') 2.0
# Now ('MITF', 'I-GENE') 1.0
# Now ('unassembled', 'O') 1.0
# Now ('Pediatric', 'O') 3.0
# Now ('etiocholanolone', 'O') 1.0
# Now ('1664', 'O') 1.0
# Now ('disconnected', 'O') 1.0
# Now ('GBF1', 'I-GENE') 1.0
# Now ('111In', 'O') 2.0
# Now ('Spc110p', 'I-GENE') 1.0
# Now ('bordering', 'O') 2.0
# Now ('TMV', 'O') 1.0
# Now ('EUS4', 'I-GENE') 1.0
# Now ('sildenafil', 'O') 2.0
# Now ('aloud', 'O') 1.0
# Now ('viscinity', 'O') 1.0
# Now ('congenic', 'O') 1.0
# Now ('ssd', 'I-GENE') 1.0
# Now ('opposing', 'O') 3.0
# Now ('trained', 'O') 4.0
# Now ('chickens', 'I-GENE') 1.0
# Now ('CYP3', 'I-GENE') 1.0
# Now ('tetraphasic', 'O') 1.0
# Now ('trapping', 'O') 4.0
# Now ('furred', 'O') 1.0
# Now ('1918', 'O') 1.0
# Now ('masseter', 'O') 2.0
# Now ('cavoatrial', 'O') 1.0
# Now ('SWS', 'O') 1.0
# Now ('Skylab', 'O') 2.0
# Now ('electromyographically', 'O') 1.0
# Now ('urogram', 'O') 1.0
# Now ('ME', 'O') 1.0
# Now ('Sunset', 'O') 1.0
# Now ('1782', 'O') 1.0
# Now ('osteomesopycnosis', 'O') 1.0
# Now ('GEO', 'O') 1.0
# Now ('Leninist', 'O') 1.0
# Now ('vitamins', 'O') 4.0
# Now (')]/[', 'O') 1.0
# Now ('MSGT', 'O') 1.0
# Now ('cytotactin', 'I-GENE') 1.0
# Now ('adeno', 'I-GENE') 2.0
# Now ('HT1A', 'I-GENE') 1.0
# Now ('Arachnoid', 'O') 1.0
# Now ('IIB', 'O') 3.0
# Now ('MEHP', 'O') 1.0
# Now ('ErbA', 'I-GENE') 1.0
# Now ('SOA', 'O') 2.0
# Now ('glycosyl', 'I-GENE') 1.0
# Now ('ddATP', 'O') 1.0
# Now ('MC3T3', 'O') 1.0
# Now ('interspecific', 'O') 3.0
# Now ('syndrome', 'I-GENE') 1.0
# Now ('Cryptococcus', 'O') 1.0
# Comparison O
#
# Now line 0
# Now line 0
# Now line 0
# alkaline I-GENE -->
# _RARE_ I-GENE
#
# Now line 0
# phosphatases I-GENE -->
# _RARE_ I-GENE
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# nucleotidase I-GENE -->
# _RARE_ I-GENE
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# [ O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# -] O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# as O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# no O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# displaced O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# 0 O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# 23 O -->
# _RARE_ O
#
# Now line 0
# vs O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# hypnotic O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# optimum O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# for O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# general O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# 15 O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# at O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# extracorporeal O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# approximated O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# VCO2 O -->
# _RARE_ O
#
# Now line 0
# ), O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# ceased O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# 25 O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# carbonic I-GENE -->
# _RARE_ I-GENE
#
# Now line 0
# Now line 0
# inhibitors O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# acetazolamide O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# methazolamide O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# dichlorphenamide O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# sulthiame O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# induced O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# O2 O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# O2 O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# blood O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# etoperidone O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# rabbit O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# endoscopically O -->
# _RARE_ O
#
# Now line 0
# whenever O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# variable O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# no O -->
# _RARE_ O
#
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0
# Now line 0

# %%
# 47
# down vote
# accepted
# Use max():

 
# Using itemgetter():

# In [53]: lis=[(101, 153), (255, 827), (361, 961)]

# In [81]: from operator import itemgetter

# In [82]: max(lis,key=itemgetter(1))[0]    #faster solution
# Out[82]: 361
